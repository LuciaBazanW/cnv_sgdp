# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy import stats

# %%
t2t =  pd.read_csv('vst_candidates_chm13t2t_cnvs.csv')
#t2t = pd.read_csv('../data/vst_')
grch37 = pd.read_csv('vst_candidates_grch37.csv')
#grch37 = pd.read_csv('../data/vst_results_grch37.csv')

# %%
t2t.columns[4:25]
#t2t['WestEurasia-Oceania']
grch37#['WestEurasia-Oceania']
# Out:
#     Chromosome      Start        End  Africa-America  \
# 0         chr1    8360201    8360201         0.32161
# 1         chr1    9846201    9846201         0.27586
# 2         chr1   13219701   13219701         0.12209
# 3         chr1   16150401   16150401         0.00136
# 4         chr1   24377601   24377601         0.00769
# ..         ...        ...        ...             ...
# 453       chr9  131183401  131183401         0.08988
# 454       chr9  134074401  134074401         0.24892
# 455       chr9  136453701  136453701         0.26558
# 456       chr9  137097701  137097701         0.00357
# 457       chr9  140245301  140245301         0.24272
#
#      Africa-CentralAsiaSiberia  Africa-EastAsia  Africa-Oceania  \
# 0                      0.19993          0.00000         0.00000
# 1                      0.04239          0.04981         0.02736
# 2                      0.03194          0.00035         0.01716
# 3                      0.01265          0.02431         0.16701
# 4                      0.11063          0.25742         0.66625
# ..                         ...              ...             ...
# 453                    0.07894          0.00025         0.00037
# 454                    0.00807          0.00186         0.06963
# 455                    0.21090          0.25679         0.01753
# 456                    0.09135          0.09335         0.42325
# 457                    0.20920          0.43720         0.24604
#
#      Africa-SouthAsia  Africa-WestEurasia  America-CentralAsiaSiberia  ...  \
# 0             0.00000             0.00000                     0.00956  ...
# 1             0.09376             0.01048                     0.12424  ...
# 2             0.00461             0.03145                     0.25941  ...
# 3             0.07339             0.06031                     0.02660  ...
# 4             0.13524             0.15024                     0.10092  ...
# ..                ...                 ...                         ...  ...
# 453           0.11241             0.33761                     0.00243  ...
# 454           0.01037             0.02543                     0.17743  ...
# 455           0.19511             0.06390                     0.00612  ...
# 456           0.21517             0.18116                     0.05796  ...
# 457           0.35019             0.18928                     0.00332  ...
#
#      CentralAsiaSiberia-EastAsia  CentralAsiaSiberia-Oceania  \
# 0                        0.20261                     0.15949
# 1                        0.00196                     0.01078
# 2                        0.03815                     0.09418
# 3                        0.00097                     0.28660
# 4                        0.06285                     0.38182
# ..                           ...                         ...
# 453                      0.07787                     0.07081
# 454                      0.00206                     0.03050
# 455                      0.00577                     0.10340
# 456                      0.00000                     0.20208
# 457                      0.06365                     0.00252
#
#      CentralAsiaSiberia-SouthAsia  CentralAsiaSiberia-WestEurasia  \
# 0                         0.19242                         0.22741
# 1                         0.02217                         0.00500
# 2                         0.06579                         0.10193
# 3                         0.13966                         0.10306
# 4                         0.00497                         0.01891
# ..                            ...                             ...
# 453                       0.00267                         0.11757
# 454                       0.02831                         0.05123
# 455                       0.00031                         0.03493
# 456                       0.03162                         0.01917
# 457                       0.02572                         0.00140
#
#      EastAsia-Oceania  EastAsia-SouthAsia  EastAsia-WestEurasia  \
# 0             0.00000             0.00000               0.00000
# 1             0.01737             0.01359               0.01488
# 2             0.01286             0.00234               0.02582
# 3             0.33966             0.18954               0.15444
# 4             0.14607             0.03831               0.01258
# ..                ...                 ...                   ...
# 453           0.00107             0.11122               0.32242
# 454           0.04679             0.01793               0.03793
# 455           0.13056             0.00897               0.07348
# 456           0.19304             0.03398               0.02388
# 457           0.04577             0.00789               0.07203
#
#      Oceania-SouthAsia  Oceania-WestEurasia  SouthAsia-WestEurasia
# 0              0.00000              0.00000                0.00000
# 1              0.04846              0.00036                0.05253
# 2              0.00593              0.00135                0.01395
# 3              0.02655              0.02565                0.00035
# 4              0.30917              0.20186                0.00683
# ..                 ...                  ...                    ...
# 453            0.09506              0.30464                0.08488
# 454            0.09668              0.14224                0.00107
# 455            0.08675              0.01170                0.03321
# 456            0.08993              0.08715                0.00077
# 457            0.01352              0.00626                0.03516
#
# [458 rows x 24 columns]

# %%
for i in t2t.columns[3:25]:
    print(i)
    print(stats.f_oneway(t2t[i], grch37[i]))
# Out:
# Africa-America
# F_onewayResult(statistic=110.39695388643808, pvalue=1.8731614576108658e-25)
# Africa-CentralAsiaSiberia
# F_onewayResult(statistic=9.870138024990652, pvalue=0.00169352630745904)
# Africa-EastAsia
# F_onewayResult(statistic=214.8659324378361, pvalue=2.716569646823499e-47)
# Africa-Oceania
# F_onewayResult(statistic=62.69529091188202, pvalue=3.1914455707809347e-15)
# Africa-SouthAsia
# F_onewayResult(statistic=139.49050939148762, pvalue=1.3166740093647006e-31)
# Africa-WestEurasia
# F_onewayResult(statistic=161.97743823717954, pvalue=2.5283508174856167e-36)
# America-CentralAsiaSiberia
# F_onewayResult(statistic=85.45851020769547, pvalue=3.952913084267912e-20)
# America-EastAsia
# F_onewayResult(statistic=40.236840198485304, pvalue=2.530447226231176e-10)
# America-Oceania
# F_onewayResult(statistic=82.5486764675543, pvalue=1.6652906155331588e-19)
# America-SouthAsia
# F_onewayResult(statistic=24.714569209771454, pvalue=6.959498328421004e-07)
# America-WestEurasia
# F_onewayResult(statistic=79.22649818836722, pvalue=8.619556072901361e-19)
# CentralAsiaSiberia-EastAsia
# F_onewayResult(statistic=186.51629216353055, pvalue=1.960903891863958e-41)
# CentralAsiaSiberia-Oceania
# F_onewayResult(statistic=23.441770836529294, pvalue=1.3419087041243549e-06)
# CentralAsiaSiberia-SouthAsia
# F_onewayResult(statistic=40.7921569914112, pvalue=1.9105041256354973e-10)
# CentralAsiaSiberia-WestEurasia
# F_onewayResult(statistic=24.163335400866874, pvalue=9.246858088405073e-07)
# EastAsia-Oceania
# F_onewayResult(statistic=56.5352449755121, pvalue=6.936362662968548e-14)
# EastAsia-SouthAsia
# F_onewayResult(statistic=4.99415683055104, pvalue=0.02549443908735705)
# EastAsia-WestEurasia
# F_onewayResult(statistic=47.246762262205436, pvalue=7.351118344807047e-12)
# Oceania-SouthAsia
# F_onewayResult(statistic=19.379640702822492, pvalue=1.102684126880215e-05)
# Oceania-WestEurasia
# F_onewayResult(statistic=47.74070990228631, pvalue=5.732635144596561e-12)
# SouthAsia-WestEurasia
# F_onewayResult(statistic=14.99502330492586, pvalue=0.00010971822373338872)

# %%
t2t_anova = pd.melt(t2t.iloc[:,3:30])
t2t_anova['assembly'] = 'T2T-CHM13'
grch37_anova = pd.melt(grch37.iloc[:,3:30])
grch37_anova['assembly'] = 'GRCh37'
input_two_anova = pd.concat([grch37_anova, t2t_anova])
input_two_anova.columns = ['Populations', 'Vstvalue', 'Assembly']
input_two_anova
# Out:
#                  Populations  Vstvalue   Assembly
# 0             Africa-America   0.32161     GRCh37
# 1             Africa-America   0.27586     GRCh37
# 2             Africa-America   0.12209     GRCh37
# 3             Africa-America   0.00136     GRCh37
# 4             Africa-America   0.00769     GRCh37
# ...                      ...       ...        ...
# 65683  SouthAsia-WestEurasia   0.01177  T2T-CHM13
# 65684  SouthAsia-WestEurasia   0.00977  T2T-CHM13
# 65685  SouthAsia-WestEurasia   0.00091  T2T-CHM13
# 65686  SouthAsia-WestEurasia   0.01003  T2T-CHM13
# 65687  SouthAsia-WestEurasia   0.00389  T2T-CHM13
#
# [75306 rows x 3 columns]

# %%
#perform two-way ANOVA
model = ols('Vstvalue ~ C(Populations) + C(Assembly) + C(Populations):C(Assembly)', data=input_two_anova).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                                 sum_sq       df           F         PR(>F)
# C(Populations)               60.823579     20.0  337.323004   0.000000e+00
# C(Assembly)                   3.164500      1.0  351.001567   3.865638e-78
# C(Populations):C(Assembly)   11.643939     20.0   64.576411  3.965600e-259
# Residual                    678.552281  75264.0         NaN            NaN

# %%
#perform two-way ANOVA
model = ols('Vstvalue ~ C(Populations) + C(Assembly) + C(Populations):C(Assembly)', data=input_two_anova).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                                 sum_sq       df           F         PR(>F)
# C(Populations)               60.823579     20.0  337.323004   0.000000e+00
# C(Assembly)                   3.164500      1.0  351.001567   3.865638e-78
# C(Populations):C(Assembly)   11.643939     20.0   64.576411  3.965600e-259
# Residual                    678.552281  75264.0         NaN            NaN

# %%
# ttest for each pair population
for i in t2t.columns[3:24]:
    print(i)
    print(stats.ttest_ind(t2t[i], grch37[i]))
# Out:
# Africa-America
# TtestResult(statistic=-10.506995473799257, pvalue=1.8731614576096634e-25, df=3584.0)
# Africa-CentralAsiaSiberia
# TtestResult(statistic=-3.141677581323496, pvalue=0.0016935263074584824, df=3584.0)
# Africa-EastAsia
# TtestResult(statistic=-14.65830591977928, pvalue=2.716569646821545e-47, df=3584.0)
# Africa-Oceania
# TtestResult(statistic=-7.918035798850748, pvalue=3.1914455707794792e-15, df=3584.0)
# Africa-SouthAsia
# TtestResult(statistic=-11.81061003468862, pvalue=1.316674009364059e-31, df=3584.0)
# Africa-WestEurasia
# TtestResult(statistic=-12.72703572074737, pvalue=2.5283508174843318e-36, df=3584.0)
# America-CentralAsiaSiberia
# TtestResult(statistic=9.244377221192108, pvalue=3.9529130842657744e-20, df=3584.0)
# America-EastAsia
# TtestResult(statistic=-6.3432515477856715, pvalue=2.530447226230129e-10, df=3584.0)
# America-Oceania
# TtestResult(statistic=-9.085630218512877, pvalue=1.6652906155322842e-19, df=3584.0)
# America-SouthAsia
# TtestResult(statistic=-4.971374981810511, pvalue=6.95949832841789e-07, df=3584.0)
# America-WestEurasia
# TtestResult(statistic=-8.900926816257236, pvalue=8.619556072896404e-19, df=3584.0)
# CentralAsiaSiberia-EastAsia
# TtestResult(statistic=13.657096769208692, pvalue=1.9609038918629647e-41, df=3584.0)
# CentralAsiaSiberia-Oceania
# TtestResult(statistic=4.841670252767047, pvalue=1.3419087041238847e-06, df=3584.0)
# CentralAsiaSiberia-SouthAsia
# TtestResult(statistic=6.386873804249714, pvalue=1.91050412563442e-10, df=3584.0)
# CentralAsiaSiberia-WestEurasia
# TtestResult(statistic=4.915621568109865, pvalue=9.246858088398988e-07, df=3584.0)
# EastAsia-Oceania
# TtestResult(statistic=-7.518992284575911, pvalue=6.936362662964408e-14, df=3584.0)
# EastAsia-SouthAsia
# TtestResult(statistic=-2.2347610231411874, pvalue=0.0254944390873477, df=3584.0)
# EastAsia-WestEurasia
# TtestResult(statistic=-6.873628027628892, pvalue=7.351118344803063e-12, df=3584.0)
# Oceania-SouthAsia
# TtestResult(statistic=-4.402231332270315, pvalue=1.1026841268797369e-05, df=3584.0)
# Oceania-WestEurasia
# TtestResult(statistic=-6.909465239965122, pvalue=5.732635144592792e-12, df=3584.0)
# SouthAsia-WestEurasia
# TtestResult(statistic=-3.8723408043360332, pvalue=0.00010971822373331719, df=3584.0)

# %%
# mannwhitney for each pair population
for i in t2t.columns[3:24]:
    print(i)
    print(stats.mannwhitneyu(t2t[i], grch37[i]))
# Out:
# Africa-America
# MannwhitneyuResult(statistic=497637.5, pvalue=4.226611918378041e-26)
# Africa-CentralAsiaSiberia
# MannwhitneyuResult(statistic=692778.0, pvalue=0.25544296250310794)
# Africa-EastAsia
# MannwhitneyuResult(statistic=450693.5, pvalue=1.0340462403251428e-37)
# Africa-Oceania
# MannwhitneyuResult(statistic=534751.0, pvalue=1.7277954164192247e-18)
# Africa-SouthAsia
# MannwhitneyuResult(statistic=487377.0, pvalue=1.893169198536559e-28)
# Africa-WestEurasia
# MannwhitneyuResult(statistic=462717.5, pvalue=1.585797937685569e-34)
# America-CentralAsiaSiberia
# MannwhitneyuResult(statistic=929832.0, pvalue=5.818268395309134e-25)
# America-EastAsia
# MannwhitneyuResult(statistic=594405.0, pvalue=3.829534426601407e-09)
# America-Oceania
# MannwhitneyuResult(statistic=560619.0, pvalue=5.310669295130456e-14)
# America-SouthAsia
# MannwhitneyuResult(statistic=652428.5, pvalue=0.0020210658105342407)
# America-WestEurasia
# MannwhitneyuResult(statistic=583746.5, pvalue=1.493329122277392e-10)
# CentralAsiaSiberia-EastAsia
# MannwhitneyuResult(statistic=1015097.0, pvalue=2.9469010789276257e-47)
# CentralAsiaSiberia-Oceania
# MannwhitneyuResult(statistic=845447.0, pvalue=4.365672559911302e-10)
# CentralAsiaSiberia-SouthAsia
# MannwhitneyuResult(statistic=875888.0, pvalue=1.2442994592193769e-14)
# CentralAsiaSiberia-WestEurasia
# MannwhitneyuResult(statistic=872658.0, pvalue=4.182138223675095e-14)
# EastAsia-Oceania
# MannwhitneyuResult(statistic=581102.0, pvalue=6.383542155007282e-11)
# EastAsia-SouthAsia
# MannwhitneyuResult(statistic=668392.5, pvalue=0.020576266939346815)
# EastAsia-WestEurasia
# MannwhitneyuResult(statistic=607257.5, pvalue=1.3649276089738382e-07)
# Oceania-SouthAsia
# MannwhitneyuResult(statistic=597854.0, pvalue=1.0374662398439448e-08)
# Oceania-WestEurasia
# MannwhitneyuResult(statistic=539050.5, pvalue=1.071995401245658e-17)
# SouthAsia-WestEurasia
# MannwhitneyuResult(statistic=675743.0, pvalue=0.04994432213169398)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,10))
ax = sns.boxplot(x='Populations',y='Vstvalue',data=input_two_anova,hue='Assembly', palette= "Set2", showmeans=True)
#ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.xticks(fontsize=20, rotation=90)
plt.yticks(fontsize=20)
plt.xlabel('Populations', fontsize=20)
plt.ylabel('Vst value', fontsize=20)
plt.legend(loc=1, prop={'size': 20})
plt.savefig('../plots/distribution_vst_among_assemblies.png', transparent=True, dpi=300, bbox_inches = "tight")
#sns.boxplot(input_boxplot, rot=90)
