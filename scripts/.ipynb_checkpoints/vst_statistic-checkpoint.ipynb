# %%
import pandas as pd
from itertools import combinations
import math
import numpy as np
import statistics
from itertools import permutations
from bioinfokit import analys, visuz
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import uniform, randint
from matplotlib_venn import venn2
import copy
import random

# %%
#pd.set_option('display.max_rows', 400)
data = pd.read_csv("../data/cnvator_data_sudmant_overlapped.csv")


anotation = pd.read_csv('../data/SGDP_anotation.csv', sep=',', encoding='latin-1',  index_col=1)

data
# Out:
#                 Sample_ID Chr  Start_original  End_original      Start  \
# 0       LP6005441-DNA_A01   1          231001        237900     228416
# 1       LP6005441-DNA_A01   1          471201        551200     471226
# 2       LP6005441-DNA_A01   1          723801        728100     712534
# 3       LP6005441-DNA_A01   1         1010901       1014200    1009660
# 4       LP6005441-DNA_A01   1         4124201       4127700    4120597
# ...                   ...  ..             ...           ...        ...
# 256113          SS6004480   X       153459601     153466400  153408881
# 256114          SS6004480   X       153474401     153496200  153408881
# 256115          SS6004480   X       153498901     153518500  153408881
# 256116          SS6004480   X       154798801     154804000  154789310
# 256117          SS6004480   X       154798801     154804000  154788811
#
#               End  SIZE        SCORE        RD   LENGHT       P-VALUE  \
# 0          267160   3.0  duplication  2.089230   6900.0  0.000000e+00
# 1          471326   1.0     deletion  0.187758  80000.0  1.992160e-12
# 2          763301   3.0  duplication  1.594500   4300.0  1.120070e-02
# 3         1015541   1.0     deletion  0.498249   3300.0  5.434590e-04
# 4         4131559   1.0     deletion  0.505571   3500.0  4.553500e-11
# ...           ...   ...          ...       ...      ...           ...
# 256113  153523661   3.0  duplication  1.882080   6800.0  3.234320e-09
# 256114  153523661   3.0  duplication  1.734000  21800.0  0.000000e+00
# 256115  153523661   3.0  duplication  1.886020  19600.0  0.000000e+00
# 256116  154826421   1.0     deletion  0.315173   5200.0  3.064860e-11
# 256117  154840186   1.0     deletion  0.315173   5200.0  3.064860e-11
#
#             GAUSSIAN
# 0       5.215800e-35
# 1       2.215930e+09
# 2       1.742820e+09
# 3       2.196950e+09
# 4       2.217790e-35
# ...              ...
# 256113  7.076210e+01
# 256114  2.123580e+09
# 256115  2.117350e+07
# 256116  2.713240e+05
# 256117  2.713240e+05
#
# [256118 rows x 12 columns]

# %%
cnv = data.pivot_table(index=["Chr", "Start", "End"], 
                    columns='Sample_ID', 
                    values='RD').reset_index()
cnv.loc[cnv['Chr'] == '8']
# Out:
# Sample_ID Chr      Start        End  LP6005441-DNA_A01  LP6005441-DNA_A03  \
# 7314        8     328860     335939                NaN                NaN
# 7315        8     593901     599598           0.000000           0.000513
# 7316        8     973671     986606                NaN                NaN
# 7317        8    1233318    1236113                NaN                NaN
# 7318        8    1304525    1307677                NaN                NaN
# ...        ..        ...        ...                ...                ...
# 7790        8  145534576  145536377                NaN                NaN
# 7791        8  145616372  145619289                NaN                NaN
# 7792        8  145701887  145708679                NaN                NaN
# 7793        8  146195179  146224164                NaN                NaN
# 7794        8  146279935  146301739           0.021105           0.023924
#
# Sample_ID  LP6005441-DNA_A04  LP6005441-DNA_A05  LP6005441-DNA_A06  \
# 7314                     NaN                NaN                NaN
# 7315                     NaN           0.000000            0.45164
# 7316                0.464672           0.479631                NaN
# 7317                     NaN                NaN                NaN
# 7318                     NaN                NaN                NaN
# ...                      ...                ...                ...
# 7790                     NaN                NaN                NaN
# 7791                     NaN                NaN                NaN
# 7792                     NaN                NaN                NaN
# 7793                     NaN                NaN                NaN
# 7794                0.023383           0.023680                NaN
#
# Sample_ID  LP6005441-DNA_A08  LP6005441-DNA_A09  ...  SS6004471  SS6004472  \
# 7314                     NaN                NaN  ...        NaN        NaN
# 7315                     NaN           0.408189  ...   0.522202        NaN
# 7316                0.451451           0.330004  ...        NaN        NaN
# 7317                     NaN                NaN  ...        NaN        NaN
# 7318                     NaN                NaN  ...        NaN        NaN
# ...                      ...                ...  ...        ...        ...
# 7790                     NaN                NaN  ...        NaN        NaN
# 7791                     NaN                NaN  ...        NaN        NaN
# 7792                     NaN                NaN  ...        NaN        NaN
# 7793                     NaN                NaN  ...        NaN        NaN
# 7794                0.264698           0.024138  ...   0.091354        NaN
#
# Sample_ID  SS6004473  SS6004474  SS6004475  SS6004476  SS6004477  SS6004478  \
# 7314             NaN        NaN        NaN        NaN        NaN        NaN
# 7315             NaN   0.001043   0.512552   0.486635   0.127359   0.495626
# 7316             NaN        NaN        NaN        NaN        NaN        NaN
# 7317             NaN        NaN        NaN        NaN        NaN        NaN
# 7318             NaN        NaN        NaN        NaN        NaN        NaN
# ...              ...        ...        ...        ...        ...        ...
# 7790             NaN        NaN        NaN        NaN        NaN        NaN
# 7791             NaN        NaN        NaN        NaN        NaN        NaN
# 7792             NaN        NaN        NaN        NaN        NaN        NaN
# 7793             NaN        NaN        NaN        NaN        NaN        NaN
# 7794        0.001185   0.000729   0.001157   0.000725        NaN        NaN
#
# Sample_ID  SS6004479  SS6004480
# 7314             NaN        NaN
# 7315        0.511263        NaN
# 7316             NaN        NaN
# 7317             NaN        NaN
# 7318             NaN        NaN
# ...              ...        ...
# 7790             NaN        NaN
# 7791             NaN   0.298549
# 7792             NaN        NaN
# 7793             NaN        NaN
# 7794        0.027811   0.001416
#
# [481 rows x 279 columns]

# %%
coordinates = cnv.iloc[:,0:2]
cnvs = cnv.iloc[:,3:284]
cnvs = cnvs.T
cnvs = cnvs.fillna(2)
cnvs
# Out:
#                        0         1         2     3     4     5        6     \
# Sample_ID
# LP6005441-DNA_A01  2.089230  0.187758  1.594500   2.0   2.0   2.0  2.00000
# LP6005441-DNA_A03  1.098060  0.795844  2.104280   2.0   2.0   2.0  2.00000
# LP6005441-DNA_A04  1.088959  0.089448  2.000000   2.0   2.0   2.0  2.00000
# LP6005441-DNA_A05  1.945120  0.000136  2.000000   2.0   2.0   2.0  2.00000
# LP6005441-DNA_A06  1.743018  0.002116  2.000000   2.0   2.0   2.0  2.00000
# ...                     ...       ...       ...   ...   ...   ...      ...
# SS6004476          2.087340  0.000687  2.417060   2.0   2.0   2.0  1.46004
# SS6004477          0.971431  0.289939  2.417685   2.0   2.0   2.0  2.00000
# SS6004478          1.032574  0.088507  2.628050   2.0   2.0   2.0  2.00000
# SS6004479          1.820703  0.000452  2.000000   2.0   2.0   2.0  2.00000
# SS6004480          1.947480  0.000258  2.000000   2.0   2.0   2.0  2.00000
#
#                    7     8         9     ...     8640     8641      8642  \
# Sample_ID                                ...
# LP6005441-DNA_A01   2.0   2.0  2.000000  ...  2.00000  2.00000  2.000000
# LP6005441-DNA_A03   2.0   2.0  2.000000  ...  2.00000  2.00000  2.000000
# LP6005441-DNA_A04   2.0   2.0  2.000000  ...  2.00000  2.00000  2.000000
# LP6005441-DNA_A05   2.0   2.0  2.000000  ...  2.00000  1.61902  2.000000
# LP6005441-DNA_A06   2.0   2.0  2.000000  ...  2.00000  2.00000  2.000000
# ...                 ...   ...       ...  ...      ...      ...       ...
# SS6004476           2.0   2.0  0.401630  ...  2.00000  2.00000  0.162154
# SS6004477           2.0   2.0  2.000000  ...  2.00000  2.00000  2.000000
# SS6004478           2.0   2.0  0.307040  ...  0.53303  2.00000  2.000000
# SS6004479           2.0   2.0  0.242527  ...  2.00000  2.00000  2.000000
# SS6004480           2.0   2.0  0.498605  ...  2.00000  2.00000  2.000000
#
#                        8643  8644  8645      8646      8647  8648      8649
# Sample_ID
# LP6005441-DNA_A01  2.000000   2.0   2.0  2.000000  2.000000   2.0  2.000000
# LP6005441-DNA_A03  2.000000   2.0   2.0  0.563718  0.563718   2.0  0.532579
# LP6005441-DNA_A04  2.000000   2.0   2.0  0.062768  0.062768   2.0  2.000000
# LP6005441-DNA_A05  2.000000   2.0   2.0  0.118046  0.118046   2.0  2.000000
# LP6005441-DNA_A06  2.000000   2.0   2.0  0.097334  0.097334   2.0  2.000000
# ...                     ...   ...   ...       ...       ...   ...       ...
# SS6004476          0.162154   2.0   2.0  0.167378  0.167378   2.0  2.000000
# SS6004477          2.000000   2.0   2.0  2.000000  2.000000   2.0  0.009885
# SS6004478          2.000000   2.0   2.0  2.000000  2.000000   2.0  0.001413
# SS6004479          2.000000   2.0   2.0  0.076623  0.076623   2.0  2.000000
# SS6004480          2.000000   2.0   2.0  0.315173  0.315173   2.0  2.000000
#
# [276 rows x 8650 columns]

# %%
features = anotation.loc[:,["7-Gender","10-Region", "11-Country",]]
dt = features.merge(cnvs, left_index=True, right_index=True)
dt.var()
# Out:
# 0       0.187688
# 1       0.020266
# 2       0.044329
# 3       0.005441
# 4       0.011714
#           ...
# 8645    0.089170
# 8646    0.784804
# 8647    0.787097
# 8648    0.016542
# 8649    0.759227
# Length: 8650, dtype: float64

# %%
def vst(x, y):
    
    
    ####### Groupby regions #######
    ######## V = within-population variance ######
    vx = np.var(x, axis=0)
    vy = np.var(y, axis=0)
    ########### N =  numbers of individuals sampled from population each cnv ##############    
    nx = x.drop(columns = ['7-Gender', '10-Region', '11-Country'])
    nx = nx.count()
    ny = y.drop(columns = ['7-Gender', '10-Region', '11-Country'])
    ny = ny.count()


    ######## Vt = total variance across all individuals of the pair of populations ########
    vt = pd.concat([x,y]).var()
    ########## Vs ################## 
    ### Vs = (V1*n1+V2*n2)/(n1+n2) 
    ## where V1 is the within-population variance of population 1, 
    ## V2 is the within population variance of population 2, 
    #n1 and n2 are the numbers of individuals sampled from population 1 and 2, respectively.
    v1 = vx*nx
    v2 = vy*ny
    ns = nx+ny
    vs = (v1+v2)/ ns
    ########## Vst #################
    #####(VT−VS)/VT
    
    vst = (vt-vs)/vt
    
        
    return(vst)

# %%
####### Groupby regions #######
dt_group = dt.groupby('10-Region')

dt_groupped = []
regions = anotation['10-Region'].unique()
for i in regions:
    dt_groupped.append(dt_group.get_group(str(i)))
    

#### Names to pair-population
regions = dt['10-Region'].unique()
combination_names = []
for i in list(combinations(regions,2)):
    combination_names.append(i[0]+str('-')+i[1])

# %%
## VST for pair-population
vst_dt = []

combination_regions = list(combinations([0,1,2,3,4,5,6],2))
for region in combination_regions:
        statistic = vst(dt_groupped[region[0]], dt_groupped[region[1]])
        vst_dt.append(statistic)

vst_dt = pd.DataFrame(vst_dt).set_axis(combination_names)
#vst_dt = vst_dt.T
vst_dt
# Out:
#                                     0         1         2         3     \
# WestEurasia-SouthAsia           0.008884  0.016558  0.014467  0.013534
# WestEurasia-Africa              0.015886  0.086130  0.053381  0.013514
# WestEurasia-CentralAsiaSiberia  0.033260  0.010014  0.020774  0.034423
# WestEurasia-Oceania             0.042020  0.018624  0.026426  0.013514
# WestEurasia-America             0.015877  0.044205  0.047619  0.013514
# WestEurasia-EastAsia            0.008413  0.008587  0.012816  0.023858
# SouthAsia-Africa                0.019851  0.125906  0.096191  0.034012
# SouthAsia-CentralAsiaSiberia    0.046672  0.021525  0.053016  0.024609
# SouthAsia-Oceania               0.057050  0.015914  0.054809  0.031694
# SouthAsia-America               0.022844  0.079177  0.099500  0.031376
# SouthAsia-EastAsia              0.012007  0.021503  0.011772  0.015046
# Africa-CentralAsiaSiberia       0.023527  0.059966  0.030358  0.060276
# Africa-Oceania                  0.091383  0.172695  0.017009       NaN
# Africa-America                  0.015210  0.043474  0.015208       NaN
# Africa-EastAsia                 0.021106  0.083806  0.064234  0.043606
# CentralAsiaSiberia-Oceania      0.136880  0.027333  0.022194  0.054885
# CentralAsiaSiberia-America      0.026065  0.042704  0.048435  0.054093
# CentralAsiaSiberia-EastAsia     0.045390  0.013703  0.034330  0.015487
# Oceania-America                 0.082299  0.118168  0.024874       NaN
# Oceania-EastAsia                0.047209  0.025736  0.039126  0.037227
# America-EastAsia                0.022508  0.047460  0.058325  0.036373
#
#                                     4         5         6         7     \
# WestEurasia-SouthAsia           0.010292  0.034538  0.017628  0.014344
# WestEurasia-Africa              0.008485       NaN  0.013514  0.018990
# WestEurasia-CentralAsiaSiberia  0.013267  0.037037  0.028291  0.023660
# WestEurasia-Oceania             0.016186       NaN  0.031798  0.022337
# WestEurasia-America             0.031375       NaN  0.035331  0.013514
# WestEurasia-EastAsia            0.012139  0.035371  0.040967  0.022884
# SouthAsia-Africa                0.013248  0.032879  0.025422  0.015749
# SouthAsia-CentralAsiaSiberia    0.015773  0.015773  0.017173  0.017173
# SouthAsia-Oceania               0.030873  0.030873  0.018708  0.016706
# SouthAsia-America               0.030675  0.030599  0.020606  0.025491
# SouthAsia-EastAsia              0.012353  0.012353  0.021344  0.013802
# Africa-CentralAsiaSiberia       0.017176  0.037037  0.037037  0.015097
# Africa-Oceania                  0.022727       NaN  0.041667  0.016385
# Africa-America                  0.033800       NaN  0.045455  0.022727
# Africa-EastAsia                 0.014286  0.032608  0.043001  0.012471
# CentralAsiaSiberia-Oceania      0.037037  0.037037  0.019667  0.019945
# CentralAsiaSiberia-America      0.030109  0.037037  0.020788  0.037037
# CentralAsiaSiberia-EastAsia     0.013701  0.013701  0.016483  0.013701
# Oceania-America                 0.045455       NaN  0.021883  0.041667
# Oceania-EastAsia                0.029411  0.029411  0.016320  0.014568
# America-EastAsia                0.026191  0.028985  0.015834  0.028985
#
#                                     8         9     ...      8640      8641  \
# WestEurasia-SouthAsia           0.014477  0.027724  ...  0.011303  0.023300
# WestEurasia-Africa              0.018990  0.009505  ...  0.031610  0.024074
# WestEurasia-CentralAsiaSiberia  0.023660  0.010663  ...  0.011309  0.021119
# WestEurasia-Oceania             0.013514  0.014405  ...  0.010951  0.015257
# WestEurasia-America             0.028320  0.016199  ...  0.024736  0.020044
# WestEurasia-EastAsia            0.014380  0.009201  ...  0.032105  0.016105
# SouthAsia-Africa                0.015713  0.044853  ...  0.025641       NaN
# SouthAsia-CentralAsiaSiberia    0.017125  0.059535  ...  0.015266       NaN
# SouthAsia-Oceania               0.025641  0.068305  ...  0.016301  0.041667
# SouthAsia-America               0.019655  0.075364  ...  0.025641       NaN
# SouthAsia-EastAsia              0.011948  0.031916  ...  0.025641  0.021739
# Africa-CentralAsiaSiberia       0.015097  0.014092  ...  0.037037       NaN
# Africa-Oceania                  0.022727  0.016104  ...  0.041667  0.041667
# Africa-America                  0.015722  0.017627  ...       NaN       NaN
# Africa-EastAsia                 0.013894  0.015137  ...       NaN  0.021739
# CentralAsiaSiberia-Oceania      0.037037  0.021366  ...  0.019729  0.041667
# CentralAsiaSiberia-America      0.020540  0.023451  ...  0.037037       NaN
# CentralAsiaSiberia-EastAsia     0.014413  0.017575  ...  0.037037  0.021739
# Oceania-America                 0.045455  0.021900  ...  0.041667  0.041667
# Oceania-EastAsia                0.021739  0.024421  ...  0.041667  0.014304
# America-EastAsia                0.016080  0.027558  ...       NaN  0.021739
#
#                                     8642      8643      8644      8645  \
# WestEurasia-SouthAsia           0.014483  0.010429  0.017239  0.008850
# WestEurasia-Africa              0.031904  0.023734  0.017536  0.032649
# WestEurasia-CentralAsiaSiberia  0.010489  0.010033  0.016405  0.017178
# WestEurasia-Oceania             0.025690  0.020262  0.016164  0.016873
# WestEurasia-America             0.028447  0.039858  0.015994  0.016658
# WestEurasia-EastAsia            0.010162  0.008350  0.017648  0.018752
# SouthAsia-Africa                0.025641  0.025641       NaN  0.033680
# SouthAsia-CentralAsiaSiberia    0.027361  0.016090       NaN  0.025641
# SouthAsia-Oceania               0.025641  0.025641       NaN  0.025641
# SouthAsia-America               0.064214  0.064214       NaN  0.025641
# SouthAsia-EastAsia              0.013386  0.013386       NaN  0.025641
# Africa-CentralAsiaSiberia       0.060650  0.037037       NaN  0.056794
# Africa-Oceania                       NaN       NaN       NaN  0.054443
# Africa-America                  0.107641  0.107641       NaN  0.052749
# Africa-EastAsia                 0.032607  0.032607       NaN  0.067841
# CentralAsiaSiberia-Oceania      0.055174  0.037037       NaN       NaN
# CentralAsiaSiberia-America      0.033951  0.055412       NaN       NaN
# CentralAsiaSiberia-EastAsia     0.018829  0.013781       NaN       NaN
# Oceania-America                 0.095137  0.095137       NaN       NaN
# Oceania-EastAsia                0.029411  0.029411       NaN       NaN
# America-EastAsia                0.049282  0.049282       NaN       NaN
#
#                                     8646      8647      8648      8649
# WestEurasia-SouthAsia           0.008859  0.008850  0.013514  0.009187
# WestEurasia-Africa              0.057872  0.056645  0.015818  0.020068
# WestEurasia-CentralAsiaSiberia  0.018272  0.018560  0.013514  0.015872
# WestEurasia-Oceania             0.159491  0.157031  0.013514  0.133432
# WestEurasia-America             0.010662  0.010722  0.018580  0.021417
# WestEurasia-EastAsia            0.012852  0.013118  0.013514  0.008413
# SouthAsia-Africa                0.060295  0.060295  0.022727  0.027724
# SouthAsia-CentralAsiaSiberia    0.025743  0.025743       NaN  0.019286
# SouthAsia-Oceania               0.191008  0.191008       NaN  0.174469
# SouthAsia-America               0.016814  0.016814  0.045455  0.033814
# SouthAsia-EastAsia              0.016864  0.016864       NaN  0.012559
# Africa-CentralAsiaSiberia       0.111936  0.111936  0.022727  0.047939
# Africa-Oceania                  0.062135  0.062135  0.022727  0.093353
# Africa-America                  0.068730  0.068730  0.048925  0.015268
# Africa-EastAsia                 0.098846  0.098846  0.022727  0.021577
# CentralAsiaSiberia-Oceania      0.302993  0.302993       NaN  0.243187
# CentralAsiaSiberia-America      0.028141  0.028141  0.045455  0.061087
# CentralAsiaSiberia-EastAsia     0.014983  0.014983       NaN  0.022441
# Oceania-America                 0.240218  0.240218  0.045455  0.107166
# Oceania-EastAsia                0.253288  0.253288       NaN  0.160847
# America-EastAsia                0.017088  0.017088  0.045455  0.026495
#
# [21 rows x 8650 columns]

# %%
filtering_vst = pd.DataFrame(vst_dt)>=0.2
filtering_vst = filtering_vst.loc[:, filtering_vst.any()]
#filtering_vst = filtering_vst.set_axis(combination_names)
filtering_vst
# Out:
#                                  36     37     49     51     55     80    \
# WestEurasia-SouthAsia           False  False  False  False  False  False
# WestEurasia-Africa              False  False  False  False  False  False
# WestEurasia-CentralAsiaSiberia   True  False  False  False  False  False
# WestEurasia-Oceania             False  False  False  False  False  False
# WestEurasia-America              True   True  False  False  False  False
# WestEurasia-EastAsia            False  False  False  False  False  False
# SouthAsia-Africa                False  False  False  False  False  False
# SouthAsia-CentralAsiaSiberia     True  False  False  False   True  False
# SouthAsia-Oceania               False  False  False  False  False   True
# SouthAsia-America                True  False  False  False  False  False
# SouthAsia-EastAsia              False  False  False  False  False  False
# Africa-CentralAsiaSiberia        True  False  False  False  False  False
# Africa-Oceania                  False  False   True  False   True   True
# Africa-America                   True   True   True  False  False  False
# Africa-EastAsia                 False  False  False  False  False   True
# CentralAsiaSiberia-Oceania      False  False   True  False   True   True
# CentralAsiaSiberia-America      False  False   True  False  False  False
# CentralAsiaSiberia-EastAsia      True  False  False  False  False  False
# Oceania-America                  True   True  False  False  False   True
# Oceania-EastAsia                False  False  False  False   True  False
# America-EastAsia                 True  False  False   True  False   True
#
#                                  105    175    176    177   ...   8549   8550  \
# WestEurasia-SouthAsia           False  False  False  False  ...  False  False
# WestEurasia-Africa              False  False  False  False  ...  False  False
# WestEurasia-CentralAsiaSiberia  False  False  False   True  ...  False  False
# WestEurasia-Oceania             False  False  False   True  ...  False  False
# WestEurasia-America             False   True  False   True  ...  False  False
# WestEurasia-EastAsia            False  False  False   True  ...  False  False
# SouthAsia-Africa                False  False  False  False  ...  False  False
# SouthAsia-CentralAsiaSiberia    False   True  False  False  ...   True  False
# SouthAsia-Oceania               False  False  False   True  ...  False  False
# SouthAsia-America               False   True   True  False  ...   True   True
# SouthAsia-EastAsia              False  False  False  False  ...  False  False
# Africa-CentralAsiaSiberia       False  False  False   True  ...  False  False
# Africa-Oceania                  False  False  False   True  ...  False  False
# Africa-America                   True   True   True   True  ...  False   True
# Africa-EastAsia                 False  False  False   True  ...  False  False
# CentralAsiaSiberia-Oceania      False  False  False  False  ...   True   True
# CentralAsiaSiberia-America      False  False  False  False  ...  False  False
# CentralAsiaSiberia-EastAsia     False  False  False  False  ...  False  False
# Oceania-America                 False  False   True  False  ...   True   True
# Oceania-EastAsia                False  False  False  False  ...  False  False
# America-EastAsia                False  False   True  False  ...  False   True
#
#                                  8551   8562   8563   8586   8588   8646  \
# WestEurasia-SouthAsia           False  False  False  False  False  False
# WestEurasia-Africa              False  False  False   True  False  False
# WestEurasia-CentralAsiaSiberia  False  False  False  False  False  False
# WestEurasia-Oceania             False  False  False  False  False  False
# WestEurasia-America             False   True   True  False  False  False
# WestEurasia-EastAsia            False  False  False  False  False  False
# SouthAsia-Africa                False  False  False  False  False  False
# SouthAsia-CentralAsiaSiberia    False  False  False  False  False  False
# SouthAsia-Oceania               False  False  False  False  False  False
# SouthAsia-America               False   True   True  False  False  False
# SouthAsia-EastAsia              False  False  False  False  False  False
# Africa-CentralAsiaSiberia       False  False  False  False  False  False
# Africa-Oceania                  False  False  False  False  False  False
# Africa-America                  False   True   True  False  False  False
# Africa-EastAsia                 False  False  False  False  False  False
# CentralAsiaSiberia-Oceania       True  False  False  False  False   True
# CentralAsiaSiberia-America      False   True   True  False  False  False
# CentralAsiaSiberia-EastAsia     False  False  False  False  False  False
# Oceania-America                  True   True   True  False   True   True
# Oceania-EastAsia                False  False  False  False  False   True
# America-EastAsia                False   True   True  False  False  False
#
#                                  8647   8649
# WestEurasia-SouthAsia           False  False
# WestEurasia-Africa              False  False
# WestEurasia-CentralAsiaSiberia  False  False
# WestEurasia-Oceania             False  False
# WestEurasia-America             False  False
# WestEurasia-EastAsia            False  False
# SouthAsia-Africa                False  False
# SouthAsia-CentralAsiaSiberia    False  False
# SouthAsia-Oceania               False  False
# SouthAsia-America               False  False
# SouthAsia-EastAsia              False  False
# Africa-CentralAsiaSiberia       False  False
# Africa-Oceania                  False  False
# Africa-America                  False  False
# Africa-EastAsia                 False  False
# CentralAsiaSiberia-Oceania       True   True
# CentralAsiaSiberia-America      False  False
# CentralAsiaSiberia-EastAsia     False  False
# Oceania-America                  True  False
# Oceania-EastAsia                 True  False
# America-EastAsia                False  False
#
# [21 rows x 574 columns]

# %%
## Coordinates anotation 
vst_dt = vst_dt.T
vst_dt.insert (0, 'chr', cnv['Chr'])
vst_dt.insert (1, 'start', cnv['Start'])
vst_dt.insert (2, 'end', cnv['End'])
vst_dt = vst_dt.round(5)
vst_dt
# Out:
#      chr      start        end  WestEurasia-SouthAsia  WestEurasia-Africa  \
# 0      1     228416     267160                0.00888             0.01589
# 1      1     471226     471326                0.01656             0.08613
# 2      1     712534     763301                0.01447             0.05338
# 3      1     763301     763482                0.01353             0.01351
# 4      1     769541     787076                0.01029             0.00848
# ...   ..        ...        ...                    ...                 ...
# 8645   X  154776475  154788811                0.00885             0.03265
# 8646   X  154788811  154840186                0.00886             0.05787
# 8647   X  154789310  154826421                0.00885             0.05665
# 8648   X  154892549  154908191                0.01351             0.01582
# 8649   X  154908191  154948137                0.00919             0.02007
#
#       WestEurasia-CentralAsiaSiberia  WestEurasia-Oceania  \
# 0                            0.03326              0.04202
# 1                            0.01001              0.01862
# 2                            0.02077              0.02643
# 3                            0.03442              0.01351
# 4                            0.01327              0.01619
# ...                              ...                  ...
# 8645                         0.01718              0.01687
# 8646                         0.01827              0.15949
# 8647                         0.01856              0.15703
# 8648                         0.01351              0.01351
# 8649                         0.01587              0.13343
#
#       WestEurasia-America  WestEurasia-EastAsia  SouthAsia-Africa  ...  \
# 0                 0.01588               0.00841           0.01985  ...
# 1                 0.04420               0.00859           0.12591  ...
# 2                 0.04762               0.01282           0.09619  ...
# 3                 0.01351               0.02386           0.03401  ...
# 4                 0.03137               0.01214           0.01325  ...
# ...                   ...                   ...               ...  ...
# 8645              0.01666               0.01875           0.03368  ...
# 8646              0.01066               0.01285           0.06030  ...
# 8647              0.01072               0.01312           0.06030  ...
# 8648              0.01858               0.01351           0.02273  ...
# 8649              0.02142               0.00841           0.02772  ...
#
#       Africa-CentralAsiaSiberia  Africa-Oceania  Africa-America  \
# 0                       0.02353         0.09138         0.01521
# 1                       0.05997         0.17269         0.04347
# 2                       0.03036         0.01701         0.01521
# 3                       0.06028             NaN             NaN
# 4                       0.01718         0.02273         0.03380
# ...                         ...             ...             ...
# 8645                    0.05679         0.05444         0.05275
# 8646                    0.11194         0.06213         0.06873
# 8647                    0.11194         0.06213         0.06873
# 8648                    0.02273         0.02273         0.04892
# 8649                    0.04794         0.09335         0.01527
#
#       Africa-EastAsia  CentralAsiaSiberia-Oceania  CentralAsiaSiberia-America  \
# 0             0.02111                     0.13688                     0.02606
# 1             0.08381                     0.02733                     0.04270
# 2             0.06423                     0.02219                     0.04843
# 3             0.04361                     0.05488                     0.05409
# 4             0.01429                     0.03704                     0.03011
# ...               ...                         ...                         ...
# 8645          0.06784                         NaN                         NaN
# 8646          0.09885                     0.30299                     0.02814
# 8647          0.09885                     0.30299                     0.02814
# 8648          0.02273                         NaN                     0.04545
# 8649          0.02158                     0.24319                     0.06109
#
#       CentralAsiaSiberia-EastAsia  Oceania-America  Oceania-EastAsia  \
# 0                         0.04539          0.08230           0.04721
# 1                         0.01370          0.11817           0.02574
# 2                         0.03433          0.02487           0.03913
# 3                         0.01549              NaN           0.03723
# 4                         0.01370          0.04545           0.02941
# ...                           ...              ...               ...
# 8645                          NaN              NaN               NaN
# 8646                      0.01498          0.24022           0.25329
# 8647                      0.01498          0.24022           0.25329
# 8648                          NaN          0.04545               NaN
# 8649                      0.02244          0.10717           0.16085
#
#       America-EastAsia
# 0              0.02251
# 1              0.04746
# 2              0.05833
# 3              0.03637
# 4              0.02619
# ...                ...
# 8645               NaN
# 8646           0.01709
# 8647           0.01709
# 8648           0.04545
# 8649           0.02649
#
# [8650 rows x 24 columns]

# %%
#sns.set_palette("bright")
for i in vst_dt.iloc[:,3:25].columns:
    plt.hist(vst_dt[i], bins=100, alpha=0.2, log=True, color="blue")

# %%
vst_dt.sort_values(by='WestEurasia-Oceania', ascending=False).head(20)
#vst_dt.loc[2148]
# Out:
#      chr      start        end  WestEurasia-SouthAsia  WestEurasia-Africa  \
# 4519  21   23654416   23666937                0.06217             0.06229
# 8456   X   93395090   93408524                0.04273             0.02600
# 5207   3  177002636  177011374                    NaN                 NaN
# 7675   8  112293525  112300229                0.23164             0.40044
# 748   10   27638079   27642286                0.01356             0.04553
# 925   10   91998319   92002307                0.04880             0.01437
# 4830   3   32101863   32119604                0.03870             0.36853
# 177    1   62642084   62656768                0.02849             0.01060
# 5557   4  106939496  106945546                0.11509             0.06721
# 1604  12   45899329   45910710                0.30734             0.02395
# 1108  11   21847054   21849813                0.01236             0.01725
# 7348   8    4122402    4125338                0.00997             0.42392
# 5044   3  114655254  114661383                0.02589             0.26240
# 6820   7     150302     161182                0.09007             0.02494
# 2799  16   58945710   58955288                0.03989             0.08652
# 908   10   84126879   84130920                0.03877             0.44065
# 1139  11   29004591   29013176                0.08394             0.09015
# 474    1  187715163  187722772                0.09439             0.32504
# 7421   8   22996194   23001045                0.01351             0.06787
# 7185   7  118823651  118834782                0.01079             0.03077
#
#       WestEurasia-CentralAsiaSiberia  WestEurasia-Oceania  \
# 4519                         0.45643              0.64545
# 8456                         0.03704              0.60566
# 5207                             NaN              0.54971
# 7675                         0.38714              0.53153
# 748                          0.15889              0.47682
# 925                          0.02477              0.46699
# 4830                         0.01182              0.45583
# 177                          0.33042              0.44138
# 5557                         0.13976              0.43353
# 1604                         0.09397              0.43198
# 1108                         0.02115              0.42882
# 7348                         0.02451              0.40545
# 5044                         0.03100              0.40049
# 6820                         0.09929              0.37616
# 2799                         0.02052              0.37494
# 908                          0.01027              0.35323
# 1139                         0.00996              0.35280
# 474                          0.25982              0.35224
# 7421                         0.01351              0.34822
# 7185                         0.00991              0.34787
#
#       WestEurasia-America  WestEurasia-EastAsia  SouthAsia-Africa  ...  \
# 4519              0.01271               0.41020           0.19753  ...
# 8456                  NaN               0.07631           0.02094  ...
# 5207                  NaN                   NaN               NaN  ...
# 7675              0.30867               0.45580           0.04718  ...
# 748               0.01810               0.20641           0.02639  ...
# 925               0.02318               0.01152           0.08179  ...
# 4830              0.03030               0.14330           0.23552  ...
# 177               0.31196               0.23015           0.04280  ...
# 5557              0.38893               0.24959           0.01930  ...
# 1604              0.24663               0.51654           0.21599  ...
# 1108              0.03980               0.01393           0.03532  ...
# 7348              0.38075               0.07224           0.37165  ...
# 5044              0.02855               0.03835           0.15946  ...
# 6820              0.01494               0.20448           0.16235  ...
# 2799              0.01079               0.07977           0.02444  ...
# 908               0.06991               0.12289           0.28789  ...
# 1139              0.21014               0.10342           0.01215  ...
# 474               0.37261               0.42197           0.13645  ...
# 7421              0.01351               0.01351           0.07939  ...
# 7185              0.03771               0.02505           0.04822  ...
#
#       Africa-CentralAsiaSiberia  Africa-Oceania  Africa-America  \
# 4519                    0.71952         0.91258         0.07669
# 8456                    0.01532         0.53334         0.02448
# 5207                        NaN         0.51384             NaN
# 7675                    0.01410         0.03842         0.02329
# 748                     0.05618         0.30749         0.02301
# 925                     0.02273         0.52041         0.02273
# 4830                    0.31025         0.03286         0.43676
# 177                     0.35576         0.46692         0.34804
# 5557                    0.02697         0.22607         0.17350
# 1604                    0.04704         0.37612         0.18279
# 1108                    0.01450         0.36434         0.08294
# 7348                    0.28463         0.01484         0.01526
# 5044                    0.27744         0.04412         0.25361
# 6820                    0.19744         0.50781         0.01882
# 2799                    0.10087         0.14618         0.06013
# 908                     0.40962         0.02308         0.19204
# 1139                    0.08943         0.14872         0.05465
# 474                     0.01567         0.03827         0.06339
# 7421                    0.06919         0.13786         0.06373
# 7185                    0.03585         0.27791         0.01664
#
#       Africa-EastAsia  CentralAsiaSiberia-Oceania  CentralAsiaSiberia-America  \
# 4519          0.57019                     0.12577                     0.52321
# 8456          0.04192                     0.47972                     0.03704
# 5207              NaN                     0.46718                         NaN
# 7675          0.01291                     0.04409                     0.03004
# 748           0.08024                     0.16047                     0.10626
# 925           0.02999                     0.51401                         NaN
# 4830          0.09500                     0.48584                     0.07645
# 177           0.22823                     0.04278                     0.02052
# 5557          0.08905                     0.15429                     0.11067
# 1604          0.43207                     0.31040                     0.09750
# 1108          0.03935                     0.34488                     0.10955
# 7348          0.22176                     0.31694                     0.29909
# 5044          0.33626                     0.46747                         NaN
# 6820          0.27301                     0.15067                     0.14375
# 2799          0.01128                     0.38598                     0.04545
# 908           0.16500                     0.39794                     0.09670
# 1139          0.01150                     0.44986                     0.28575
# 474           0.02843                     0.06674                     0.11107
# 7421          0.08399                     0.33333                         NaN
# 7185          0.01153                     0.48655                     0.05679
#
#       CentralAsiaSiberia-EastAsia  Oceania-America  Oceania-EastAsia  \
# 4519                      0.01636          0.76772           0.11334
# 8456                      0.03194          0.49996           0.38332
# 5207                          NaN          0.44381           0.51744
# 7675                      0.01502          0.09144           0.02863
# 748                       0.01695          0.41508           0.10579
# 925                       0.04725          0.49023           0.42737
# 4830                      0.10628          0.67897           0.17366
# 177                       0.02091          0.04725           0.06357
# 5557                      0.04111          0.02960           0.05386
# 1604                      0.32618          0.15188           0.02174
# 1108                      0.04792          0.58066           0.51488
# 7348                      0.02615          0.02229           0.22068
# 5044                          NaN          0.44409           0.51773
# 6820                      0.03500          0.42453           0.05816
# 2799                      0.09409          0.30945           0.15425
# 908                       0.11769          0.15842           0.10484
# 1139                      0.10076          0.06118           0.13821
# 474                       0.04680          0.04167           0.01642
# 7421                          NaN          0.31356           0.37775
# 7185                      0.02954          0.27459           0.28732
#
#       America-EastAsia
# 4519           0.37672
# 8456           0.05134
# 5207               NaN
# 7675           0.03273
# 748            0.11465
# 925            0.04415
# 4830           0.21254
# 177            0.01990
# 5557           0.02863
# 1604           0.12868
# 1108           0.03629
# 7348           0.20114
# 5044               NaN
# 6820           0.19063
# 2799           0.05502
# 908            0.01914
# 1139           0.04781
# 474            0.03644
# 7421               NaN
# 7185           0.01795
#
# [20 rows x 24 columns]

# %%
#### SAVING VST FILE
vst_dt.to_csv('../data/vst_results.csv')
vst_dt
# Out:
#      chr      start        end  WestEurasia-SouthAsia  WestEurasia-Africa  \
# 0      1     228416     267160                0.00888             0.01589
# 1      1     471226     471326                0.01656             0.08613
# 2      1     712534     763301                0.01447             0.05338
# 3      1     763301     763482                0.01353             0.01351
# 4      1     769541     787076                0.01029             0.00848
# ...   ..        ...        ...                    ...                 ...
# 8645   X  154776475  154788811                0.00885             0.03265
# 8646   X  154788811  154840186                0.00886             0.05787
# 8647   X  154789310  154826421                0.00885             0.05665
# 8648   X  154892549  154908191                0.01351             0.01582
# 8649   X  154908191  154948137                0.00919             0.02007
#
#       WestEurasia-CentralAsiaSiberia  WestEurasia-Oceania  \
# 0                            0.03326              0.04202
# 1                            0.01001              0.01862
# 2                            0.02077              0.02643
# 3                            0.03442              0.01351
# 4                            0.01327              0.01619
# ...                              ...                  ...
# 8645                         0.01718              0.01687
# 8646                         0.01827              0.15949
# 8647                         0.01856              0.15703
# 8648                         0.01351              0.01351
# 8649                         0.01587              0.13343
#
#       WestEurasia-America  WestEurasia-EastAsia  SouthAsia-Africa  ...  \
# 0                 0.01588               0.00841           0.01985  ...
# 1                 0.04420               0.00859           0.12591  ...
# 2                 0.04762               0.01282           0.09619  ...
# 3                 0.01351               0.02386           0.03401  ...
# 4                 0.03137               0.01214           0.01325  ...
# ...                   ...                   ...               ...  ...
# 8645              0.01666               0.01875           0.03368  ...
# 8646              0.01066               0.01285           0.06030  ...
# 8647              0.01072               0.01312           0.06030  ...
# 8648              0.01858               0.01351           0.02273  ...
# 8649              0.02142               0.00841           0.02772  ...
#
#       Africa-CentralAsiaSiberia  Africa-Oceania  Africa-America  \
# 0                       0.02353         0.09138         0.01521
# 1                       0.05997         0.17269         0.04347
# 2                       0.03036         0.01701         0.01521
# 3                       0.06028             NaN             NaN
# 4                       0.01718         0.02273         0.03380
# ...                         ...             ...             ...
# 8645                    0.05679         0.05444         0.05275
# 8646                    0.11194         0.06213         0.06873
# 8647                    0.11194         0.06213         0.06873
# 8648                    0.02273         0.02273         0.04892
# 8649                    0.04794         0.09335         0.01527
#
#       Africa-EastAsia  CentralAsiaSiberia-Oceania  CentralAsiaSiberia-America  \
# 0             0.02111                     0.13688                     0.02606
# 1             0.08381                     0.02733                     0.04270
# 2             0.06423                     0.02219                     0.04843
# 3             0.04361                     0.05488                     0.05409
# 4             0.01429                     0.03704                     0.03011
# ...               ...                         ...                         ...
# 8645          0.06784                         NaN                         NaN
# 8646          0.09885                     0.30299                     0.02814
# 8647          0.09885                     0.30299                     0.02814
# 8648          0.02273                         NaN                     0.04545
# 8649          0.02158                     0.24319                     0.06109
#
#       CentralAsiaSiberia-EastAsia  Oceania-America  Oceania-EastAsia  \
# 0                         0.04539          0.08230           0.04721
# 1                         0.01370          0.11817           0.02574
# 2                         0.03433          0.02487           0.03913
# 3                         0.01549              NaN           0.03723
# 4                         0.01370          0.04545           0.02941
# ...                           ...              ...               ...
# 8645                          NaN              NaN               NaN
# 8646                      0.01498          0.24022           0.25329
# 8647                      0.01498          0.24022           0.25329
# 8648                          NaN          0.04545               NaN
# 8649                      0.02244          0.10717           0.16085
#
#       America-EastAsia
# 0              0.02251
# 1              0.04746
# 2              0.05833
# 3              0.03637
# 4              0.02619
# ...                ...
# 8645               NaN
# 8646           0.01709
# 8647           0.01709
# 8648           0.04545
# 8649           0.02649
#
# [8650 rows x 24 columns]

# %%
# Simulate DataFrame
#vst_dt['i']= vst_dt.index
vst_dt["i"] = pd.to_numeric(vst_dt.index, downcast="float")

#vst_dt['log_West_Oceania'] = np.log2(vst_dt['WestEurasia-Oceania'])

# Generate Manhattan plot: (#optional tweaks for relplot: linewidth=0, s=9)
plot = sns.relplot(data=vst_dt, x='i', y='WestEurasia-Oceania', aspect=3.7, 
                  hue='chr', palette = 'bright', legend=None) 
chrom_df=vst_dt.groupby('chr')['i'].median()
plot.ax.set_xlabel('chr'); plot.ax.set_xticks(chrom_df);
plot.ax.set_xticklabels(chrom_df.index)
plot.fig.suptitle('WestvsOceania');

# %% [markdown]
# <h1>  Sudmant data

# %%
header= ['Sample', 'Region', 'Country', 'Sample_ID', 'Sex']
studmant_anotation = pd.read_csv('/branchinecta/jbazanwilliamson/Studmant_anotation.csv', names=header, index_col=0)#Studmant data

studmant_data = pd.read_csv('/branchinecta/jbazanwilliamson/Studmant_cnvs.csv')
#studmant_data

# %%
coordinates = studmant_data.iloc[:,0:2]
cnvs = studmant_data.iloc[:,6:284]
cnvs = cnvs.T
cnvs = cnvs.fillna(2)
statistics.variance(cnvs[1])
#cnvs[1].var()
# Out:
# 4.8401233911286035

# %%
sudmant_features = studmant_anotation.loc[:,["Region","Country", "Sex",]]
sudmant_dt = sudmant_features.merge(cnvs, left_index=True, right_index=True)
sudmant_features = sudmant_dt.loc[:,['Region', 'Country', 'Sex']]
sudmant_dt = sudmant_dt[sudmant_dt['Region'].notna()]
sudmant_dt
# Out:
#                               Region        Country Sex   0   1  2  3  4   5  \
# AFR_BantuKenya_HGDP01414_F       AFR     BantuKenya   F  -1  11  2  2  2  23
# AFR_BantuKenya_HGDP01417_M       AFR     BantuKenya   M  22  10  2  2  2  24
# AFR_BantuSEHerero_HGDP01028_M    AFR  BantuSEHerero   M  22  10  1  2  2  24
# AFR_BantuSEHerero_HGDP01035_M    AFR  BantuSEHerero   M  -1  11  2  2  2  25
# AFR_BantuSETswana_HGDP01030_M    AFR  BantuSETswana   M  23  -1  2  2  2  26
# ...                              ...            ...  ..  ..  .. .. .. ..  ..
# WEA_SpainIBS_HG01504_F           WEA       SpainIBS   F  -1  12  2  2  2  24
# WEA_Tuscan_HGDP01163_M           WEA         Tuscan   M  22  10  2  2  2  25
# WEA_Tuscan_HGDP01168_F           WEA         Tuscan   F  -1  12  2  2  2  23
# WEA_YemeniteJew_4695_F           WEA    YemeniteJew   F  22  10  2  2  2  23
# WEA_YemeniteJew_5433_M           WEA    YemeniteJew   M  22  10  2  2  2  23
#
#                                6  ...  15002  15003  15004  15005  15006  \
# AFR_BantuKenya_HGDP01414_F     2  ...      2      2      2      2      2
# AFR_BantuKenya_HGDP01417_M     2  ...      2      2      1      1      1
# AFR_BantuSEHerero_HGDP01028_M  2  ...      2      2      1      1      1
# AFR_BantuSEHerero_HGDP01035_M  2  ...      2      2      2      1      1
# AFR_BantuSETswana_HGDP01030_M  1  ...      2      2      1      1      1
# ...                           ..  ...    ...    ...    ...    ...    ...
# WEA_SpainIBS_HG01504_F         2  ...      2      2      2      2      2
# WEA_Tuscan_HGDP01163_M         2  ...      2      2      1      1      1
# WEA_Tuscan_HGDP01168_F         2  ...      2      2      3      2      2
# WEA_YemeniteJew_4695_F         2  ...      2      2      2      2      2
# WEA_YemeniteJew_5433_M         2  ...      2      2      1      1      1
#
#                                15007  15008  15009  15010  15011
# AFR_BantuKenya_HGDP01414_F         2      2      6      2      2
# AFR_BantuKenya_HGDP01417_M         1      1      6      1      1
# AFR_BantuSEHerero_HGDP01028_M      1      1      5      1      1
# AFR_BantuSEHerero_HGDP01035_M      1      1      6      1      1
# AFR_BantuSETswana_HGDP01030_M      1      1      6      1      1
# ...                              ...    ...    ...    ...    ...
# WEA_SpainIBS_HG01504_F             2      2      6      2      2
# WEA_Tuscan_HGDP01163_M             1      1      6      1      1
# WEA_Tuscan_HGDP01168_F             2      2      6      2      2
# WEA_YemeniteJew_4695_F             2      2      6      2      2
# WEA_YemeniteJew_5433_M             1      1      6      1      1
#
# [238 rows x 15015 columns]

# %%
def vst_statistic(data, region_column_name, gender_column_name, country_column_name):
    """
    data (object) = Dataframe with cnv data and features(region, country and gender)
    anotation (object) = Dataframe with only features 
    """

    ####### Data frame with features ######
    dt = data.copy()
    dt = dt.groupby(region_column_name)
    
    
    ####### Groupby regions #######
    dt_groupped = []
    regions = data[region_column_name].unique()
    for i in regions:
        dt_groupped.append(dt.get_group(str(i)))
    ######## V = within-population variance ######
    v = []
    for i in dt_groupped:
        v.append((i.var()))#You can add log2 transformation here as np.log2(i.var())
        
    ########### N =  numbers of individuals sampled from population each cnv ##############
    n = dt.count()
    n = n.drop(columns=[gender_column_name, country_column_name])
    n = n.reindex(regions)
    n = np.array(n)
    
    
    #### List of counts of regions ###
    number_of_regions = len(regions)
    numbers = []
    
    for i in range(number_of_regions):
        numbers.append(i)

    ######## Vt = total variance across all individuals of the pair of populations ########
    vt = []
    combination_regions = list(combinations(numbers,2))
    for i in combination_regions:
        pair_populations = pd.concat([dt_groupped[i[0]],dt_groupped[i[1]]])# dt_groupped[i[0]]+dt_groupped[i[1]]
        vt.append(pair_populations.var())

    ########## Vs ################## 
    ### Vs = (V1*n1+V2*n2)/(n1+n2) 
    ## where V1 is the within-population variance of population 1, 
    ## V2 is the within population variance of population 2, 
    #n1 and n2 are the numbers of individuals sampled from population 1 and 2, respectively.
    
    vs = []
    for i in combination_regions:
        v1 = v[i[0]]*n[i[0]]
        v2 = v[i[1]]*n[i[1]]
        ns = n[i[0]]+n[i[1]]
        vs_formula = (v1+v2)/ ns
        vs.append(vs_formula)
     
    ########## Vst #################
    #####(VT−VS)/VT
    
    vst = []
    for i in range(len(combination_regions)):
        vst.append(((vt[i])-(vs[i]))/(vt[i]))
        
    vst_dt = np.array(vst)
    
    vst_dt = pd.DataFrame(vst_dt)
    
    #### ADD pair-population names #####
    
    combination_names = []
    for i in list(combinations(regions,2)):
        combination_names.append(i[0]+str('-')+i[1])
    
    vst_dt = vst_dt.set_axis(combination_names)
    vst_dt = vst_dt.T
    
    return(vst_dt)

# %%
vst_sudmant = vst_statistic(sudmant_dt,'Region','Sex','Country')
vst_sudmant
# Out:
#             AFR-AMR       AFR-ARC        AFR-EA       AFR-OCN        AFR-SA  \
# 0     -1.670680e-02 -5.611246e-02  1.356810e-03 -8.946054e-04 -1.521041e-02
# 1      2.318631e-03  3.330782e-02 -6.473493e-03 -1.418707e-02 -8.560662e-03
# 2      4.087009e-15  2.536166e-15  2.088607e-15  4.087009e-15  4.718448e-15
# 3      3.011480e-15  1.641048e-15  1.342676e-15  3.011480e-15  3.656797e-15
# 4      8.750000e-03  1.219512e-03  1.339286e-02  8.750000e-03  1.022727e-02
# ...             ...           ...           ...           ...           ...
# 15007  9.453125e-02  7.352941e-02 -8.522727e-03 -2.956432e-03 -1.518784e-02
# 15008  9.453125e-02  7.352941e-02 -8.522727e-03 -9.581882e-03 -1.498774e-02
# 15009  4.750831e-02  3.846154e-03 -1.325758e-03  2.715517e-02  3.174603e-04
# 15010  9.453125e-02  7.352941e-02 -1.065969e-02 -9.581882e-03 -1.518784e-02
# 15011  1.500000e-02  9.117647e-02  1.197722e-02 -1.552306e-02 -4.609905e-03
#
#             AFR-SIB       AFR-WEA       AMR-ARC    AMR-EA   AMR-OCN  ...  \
# 0     -1.583980e-02 -9.271693e-03 -1.004297e-01 -0.002087 -0.004431  ...
# 1     -1.284061e-02  2.310721e-02  2.245902e-01 -0.005326  0.009260  ...
# 2      1.092876e-15  5.204170e-16           NaN       NaN       NaN  ...
# 3      8.743006e-16  1.734723e-16           NaN       NaN       NaN  ...
# 4      9.016393e-03  1.505102e-02           NaN       NaN       NaN  ...
# ...             ...           ...           ...       ...       ...  ...
# 15007  5.155510e-02 -1.013605e-02  2.941176e-02  0.060411  0.170611  ...
# 15008  5.155510e-02 -1.013605e-02  2.941176e-02  0.060411  0.163265  ...
# 15009  2.796610e-02  2.042105e-02  3.191891e-16  0.025150  0.000000  ...
# 15010  5.155510e-02 -1.013605e-02  2.941176e-02  0.063547  0.163265  ...
# 15011  3.128590e-02 -5.164305e-03  1.524590e-01  0.074052  0.019105  ...
#
#          EA-OCN     EA-SA    EA-SIB    EA-WEA        OCN-SA   OCN-SIB  \
# 0     -0.015387 -0.001179  0.002476  0.011311 -3.436997e-03  0.001362
# 1     -0.007499 -0.016238 -0.017936  0.014672 -1.133203e-02 -0.019884
# 2           NaN       NaN       NaN       NaN           NaN       NaN
# 3           NaN       NaN       NaN       NaN           NaN       NaN
# 4           NaN       NaN       NaN       NaN           NaN       NaN
# ...         ...       ...       ...       ...           ...       ...
# 15007  0.012041 -0.011521  0.025847 -0.005292 -5.089158e-03  0.114022
# 15008  0.002661 -0.007981  0.025847 -0.005292 -1.854744e-02  0.102174
# 15009  0.007457 -0.013395  0.007692 -0.004350  1.998401e-15       NaN
# 15010 -0.002990 -0.012853  0.030303 -0.008203 -1.329627e-02  0.102174
# 15011  0.002661 -0.011521 -0.010167 -0.002596 -1.329627e-02  0.024887
#
#             OCN-WEA        SA-SIB    SA-WEA       SIB-WEA
# 0      7.911560e-03 -2.070018e-02 -0.011423 -1.298243e-02
# 1      4.804674e-02 -2.033489e-02 -0.004420  3.974328e-03
# 2               NaN           NaN       NaN           NaN
# 3               NaN           NaN       NaN           NaN
# 4               NaN           NaN       NaN           NaN
# ...             ...           ...       ...           ...
# 15007 -3.088897e-03  5.025641e-02 -0.011878  5.133148e-02
# 15008 -7.988144e-03  5.923961e-02 -0.012763  5.133148e-02
# 15009 -5.551115e-16  2.210038e-15 -0.011905  7.025630e-16
# 15010 -7.988144e-03  5.025641e-02 -0.011878  5.133148e-02
# 15011 -9.910109e-03 -4.111535e-03 -0.011234  8.506807e-03
#
# [15012 rows x 28 columns]

# %%
#Coorrdinates
vst_sudmant.insert (0, 'chr', studmant_data['contig'])
vst_sudmant.insert (1, 'start', studmant_data['start'])
vst_sudmant.insert (2, 'end', studmant_data['end'])
vst_sudmant = vst_sudmant.round(5)
vst_sudmant
# Out:
#         chr      start        end  AFR-AMR  AFR-ARC   AFR-EA  AFR-OCN  \
# 0      chr1      12048     177033 -0.01671 -0.05611  0.00136 -0.00089
# 1      chr1      12048      89237  0.00232  0.03331 -0.00647 -0.01419
# 2      chr1   53897994   53905803  0.00000  0.00000  0.00000  0.00000
# 3      chr1  114813682  114821317  0.00000  0.00000  0.00000  0.00000
# 4      chr1  203967055  203977106  0.00875  0.00122  0.01339  0.00875
# ...     ...        ...        ...      ...      ...      ...      ...
# 15007  chrX   29599756   29609177  0.09453  0.07353 -0.00852 -0.00296
# 15008  chrX  136184011  136198455  0.09453  0.07353 -0.00852 -0.00958
# 15009  chrX   91366346   91368944  0.04751  0.00385 -0.00133  0.02716
# 15010  chrX  138508379  138510401  0.09453  0.07353 -0.01066 -0.00958
# 15011  chrX  139485661  139503893  0.01500  0.09118  0.01198 -0.01552
#
#         AFR-SA  AFR-SIB  AFR-WEA  ...   EA-OCN    EA-SA   EA-SIB   EA-WEA  \
# 0     -0.01521 -0.01584 -0.00927  ... -0.01539 -0.00118  0.00248  0.01131
# 1     -0.00856 -0.01284  0.02311  ... -0.00750 -0.01624 -0.01794  0.01467
# 2      0.00000  0.00000  0.00000  ...      NaN      NaN      NaN      NaN
# 3      0.00000  0.00000  0.00000  ...      NaN      NaN      NaN      NaN
# 4      0.01023  0.00902  0.01505  ...      NaN      NaN      NaN      NaN
# ...        ...      ...      ...  ...      ...      ...      ...      ...
# 15007 -0.01519  0.05156 -0.01014  ...  0.01204 -0.01152  0.02585 -0.00529
# 15008 -0.01499  0.05156 -0.01014  ...  0.00266 -0.00798  0.02585 -0.00529
# 15009  0.00032  0.02797  0.02042  ...  0.00746 -0.01339  0.00769 -0.00435
# 15010 -0.01519  0.05156 -0.01014  ... -0.00299 -0.01285  0.03030 -0.00820
# 15011 -0.00461  0.03129 -0.00516  ...  0.00266 -0.01152 -0.01017 -0.00260
#
#         OCN-SA  OCN-SIB  OCN-WEA   SA-SIB   SA-WEA  SIB-WEA
# 0     -0.00344  0.00136  0.00791 -0.02070 -0.01142 -0.01298
# 1     -0.01133 -0.01988  0.04805 -0.02033 -0.00442  0.00397
# 2          NaN      NaN      NaN      NaN      NaN      NaN
# 3          NaN      NaN      NaN      NaN      NaN      NaN
# 4          NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...
# 15007 -0.00509  0.11402 -0.00309  0.05026 -0.01188  0.05133
# 15008 -0.01855  0.10217 -0.00799  0.05924 -0.01276  0.05133
# 15009  0.00000      NaN -0.00000  0.00000 -0.01190  0.00000
# 15010 -0.01330  0.10217 -0.00799  0.05026 -0.01188  0.05133
# 15011 -0.01330  0.02489 -0.00991 -0.00411 -0.01123  0.00851
#
# [15012 rows x 31 columns]

# %%
vst_sudmant.sort_values(by='OCN-WEA', ascending=False)

#### SAVING VST FILE
vst_sudmant.to_csv('../data/vst_sudmant_results.csv')

# %% [markdown]
# <h1> T-test for independency

# %%
from scipy import stats

def ttest(data, region_column_name):
    """
    data (object): data with features
    regions_column_names (str): name of column of region in data
    """
    var_cnv = data.groupby(region_column_name).var()

    #### List of counts of regions ###
    regions = data[region_column_name].unique()
    number_of_regions = len(regions)
    numbers = []
    
    for i in range(number_of_regions):
        numbers.append(i)
    
    ### T-test
    ttest = []
    combination_regions = list(combinations(numbers,2))
    
    for i in combination_regions:
        ttest.append(stats.ttest_ind(var_cnv.iloc[i[0]], var_cnv.iloc[i[1]]))

    result_ttest = []
    for i in ttest:
        result_ttest.append([i[0], i[1]])
        
    #### ADD pair-population names #####    
    combination_names = []
    for i in list(combinations(var_cnv.index,2)):
        combination_names.append(i[0]+str('-')+i[1])
        
    ttest_df = pd.DataFrame(result_ttest)
    ttest_df = ttest_df.set_axis(combination_names) 
    ttest_df.columns = ['statistic', 'pvalue']

    
    return(ttest_df)

# %%
ttest_df = ttest(sudmant_dt, 'Region')

# %%
fig = plt.figure(figsize=(10,8))

ax1 = fig.add_subplot(121)
ax1.scatter(x=ttest_df['statistic'],y=ttest_df['pvalue'], alpha=0.5)

ax2 = fig.add_subplot(122)
font_size=8
bbox=[1, 0, 1, 1]
ax2.axis('off')
mpl_table = ax2.table(cellText = ttest_df.values, rowLabels = ttest_df.index, bbox=bbox, colLabels=ttest_df.columns)
mpl_table.auto_set_font_size(False)
mpl_table.set_fontsize(font_size)
plt.title("Sudmant")
# Out:
# Text(0.5, 1.0, 'Sudmant')

# %%
ttest_df = ttest(dt, '10-Region')
fig = plt.figure(figsize=(20,10))

ax1 = fig.add_subplot(121)
ax1.scatter(x=ttest_df['statistic'],y=ttest_df['pvalue'], alpha=0.5)

ax2 = fig.add_subplot(122)
font_size= 12
bbox=[1, 0, 1,1]
ax2.axis('off')
mpl_table = ax2.table(cellText = ttest_df.values, rowLabels = ttest_df.index, bbox=bbox, colLabels=ttest_df.columns)
mpl_table.auto_set_font_size(False)
mpl_table.set_fontsize(font_size)
plt.title("My Data")
# Out:
# Text(0.5, 1.0, 'My Data')

# %% [markdown]
# <h2> Computing permutation for each pair-group whole samples

# %%
def vst_gt(x, y):
    
    ####### Groupby regions #######
    ######## V = within-population variance ######
    vx = np.var(x, axis=0)
    vy = np.var(y, axis=0)
    ########### N =  numbers of individuals sampled from population each cnv ##############    
    nx = len(x)
    ny = len(y)

    ######## Vt = total variance across all individuals of the pair of populations ########
    #vt = pd.concat([x,y]).var()
    vt = np.concatenate((x,y)).var()
    ########## Vs ################## 
    ### Vs = (V1*n1+V2*n2)/(n1+n2) 
    ## where V1 is the within-population variance of population 1, 
    ## V2 is the within population variance of population 2, 
    #n1 and n2 are the numbers of individuals sampled from population 1 and 2, respectively.
    v1 = vx*nx
    v2 = vy*ny
    ns = nx+ny
    vs = (v1+v2)/ ns
    ########## Vst #################
    #####(VT−VS)/VT
    
    vst = (vt-vs)/vt
        
    return(vst)

# %%
from stattools.resampling import PermutationTest
PermutationTest
# Out:
# stattools.resampling.permutation.PermutationTest

# %%
pt = PermutationTest(dt_group.get_group(str('WestEurasia'))[176], dt_group.get_group(str('America'))[176], stat=vst_gt, n_perm=999)

# %%
p_value_ = pt.p_value()
print(f"p-value: {p_value_:.4f}")
# Out:
# p-value: 0.0090

# %%
plt.figure()
plt.hist(pt.dist, bins="auto")
plt.axvline(pt.observed, c="r", ls="--", label="Observed difference in variances")
plt.legend(loc="best", frameon=True, shadow=True)
plt.xlabel("Differences in variances")
plt.ylabel("Frequency")
plt.show()
plt.close()

# %% [markdown]
# <h2> I ran this as a job cause takes a while (~2 days)

# %%
p_value_permutation = []

combination_regions = list(combinations([0,1,2,3,4,5,6],2))
for region in combination_regions:
    
    p_value= []
    p_value_permutation.append(p_value)
    for i in range(10):
        permutation = PermutationTest(dt_groupped[region[0]][i], dt_groupped[region[1]][i], stat=vst_gt, n_perm=999)#mean_gt
        p_value.append(permutation.p_value())
# Out:
# <ipython-input-83-48d1ead41ae3>:26: RuntimeWarning: invalid value encountered in double_scalars
#   vst = (vt-vs)/vt

# %%
names = []
regions = dt['10-Region'].unique()
for i in list(combinations(regions,2)):
    names.append(i[0]+str('-')+i[1])

# %%
permutation_df = pd.DataFrame(p_value_permutation)
permutation_df = permutation_df.set_axis(names)
permutation_df
# Out:
#                                     0      1      2      3      4      5  \
# WestEurasia-SouthAsia           0.960  0.343  0.422  0.539  0.756  0.106
# WestEurasia-Africa              0.333  0.001  0.025  1.000  0.995  0.001
# WestEurasia-CentralAsiaSiberia  0.137  0.918  0.291  0.139  0.605  0.168
# WestEurasia-Oceania             0.068  0.380  0.195  0.560  0.757  0.001
# WestEurasia-America             0.467  0.058  0.068  0.967  0.213  0.001
# WestEurasia-EastAsia            0.918  0.881  0.495  0.315  0.565  0.104
# SouthAsia-Africa                0.424  0.001  0.011  0.091  0.581  0.172
# SouthAsia-CentralAsiaSiberia    0.161  0.577  0.107  0.494  0.803  0.814
# SouthAsia-Oceania               0.109  0.964  0.107  0.471  0.779  0.768
# SouthAsia-America               0.525  0.037  0.020  0.692  0.608  0.757
# SouthAsia-EastAsia              0.885  0.356  0.982  0.637  0.991  0.990
# Africa-CentralAsiaSiberia       0.408  0.018  0.289  0.130  0.603  0.240
# Africa-Oceania                  0.024  0.001  0.700  0.001  0.775  0.001
# Africa-America                  0.954  0.156  0.960  0.001  0.292  0.001
# Africa-EastAsia                 0.359  0.003  0.021  0.222  1.000  0.468
# CentralAsiaSiberia-Oceania      0.015  0.593  0.743  0.470  0.788  0.795
# CentralAsiaSiberia-America      0.630  0.348  0.204  0.443  0.662  0.796
# CentralAsiaSiberia-EastAsia     0.128  0.993  0.239  0.679  0.982  0.985
# Oceania-America                 0.102  0.008  0.717  0.001  0.349  0.001
# Oceania-EastAsia                0.136  0.395  0.203  0.327  0.435  0.416
# America-EastAsia                0.462  0.128  0.084  0.498  0.552  0.451
#
#                                     6      7      8      9
# WestEurasia-SouthAsia           0.358  0.707  0.599  0.170
# WestEurasia-Africa              1.000  0.353  0.343  0.776
# WestEurasia-CentralAsiaSiberia  0.249  0.173  0.138  0.902
# WestEurasia-Oceania             0.211  0.130  0.455  0.411
# WestEurasia-America             0.147  0.384  0.188  0.418
# WestEurasia-EastAsia            0.044  0.379  0.729  0.783
# SouthAsia-Africa                0.313  0.810  0.988  0.225
# SouthAsia-CentralAsiaSiberia    0.632  0.595  0.597  0.103
# SouthAsia-Oceania               0.574  0.843  0.929  0.025
# SouthAsia-America               0.658  0.793  0.527  0.124
# SouthAsia-EastAsia              0.455  0.922  0.916  0.499
# Africa-CentralAsiaSiberia       0.236  0.930  0.942  0.953
# Africa-Oceania                  0.118  0.995  1.000  0.664
# Africa-America                  0.303  0.940  1.000  0.749
# Africa-EastAsia                 0.143  0.854  0.653  0.390
# CentralAsiaSiberia-Oceania      0.788  0.933  0.798  0.604
# CentralAsiaSiberia-America      0.842  0.782  0.885  0.646
# CentralAsiaSiberia-EastAsia     0.829  0.894  0.900  0.762
# Oceania-America                 0.611  1.000  0.435  0.849
# Oceania-EastAsia                0.810  0.662  0.905  0.324
# America-EastAsia                0.896  0.480  0.943  0.325

# %% [markdown]
# <h1> Results from job

# %%
results_permutation = pd.read_csv("../data/permutation_results.csv", index_col=0)
results_permutation.columns = results_permutation.columns.astype(int)# df['DataFrame Column'].astype(int)
results_permutation
# Out:
#                                   0       1       2       3       4     \
# WestEurasia-SouthAsia           0.9114  0.3189  0.4430  0.6867  0.7506
# WestEurasia-Africa              0.2908  0.0026  0.0269  0.7753  0.9803
# WestEurasia-CentralAsiaSiberia  0.1060  0.7632  0.2925  0.1192  0.5670
# WestEurasia-Oceania             0.0436  0.5164  0.2940  0.5710  0.7842
# WestEurasia-America             0.6138  0.1196  0.0554  1.0000  0.1894
# WestEurasia-EastAsia            0.9166  0.8416  0.4156  0.2922  0.5462
# SouthAsia-Africa                0.3823  0.0003  0.0075  0.1119  0.6173
# SouthAsia-CentralAsiaSiberia    0.1346  0.5866  0.1072  0.4934  0.7880
# SouthAsia-Oceania               0.0576  0.9220  0.1512  0.4501  0.7622
# SouthAsia-America               0.7402  0.0917  0.0216  0.6956  0.5801
# SouthAsia-EastAsia              0.8298  0.4379  0.9492  0.6111  0.9898
# Africa-CentralAsiaSiberia       0.3922  0.0168  0.3239  0.1331  0.6866
# Africa-Oceania                  0.0086  0.0001  0.5994  0.0001  0.7660
# Africa-America                  0.8464  0.0685  0.9192  0.0001  0.2796
# Africa-EastAsia                 0.2911  0.0016  0.0263  0.2216  0.9978
# CentralAsiaSiberia-Oceania      0.0052  0.5833  0.9301  0.4668  0.7779
# CentralAsiaSiberia-America      0.4476  0.4197  0.2636  0.4688  0.6810
# CentralAsiaSiberia-EastAsia     0.1134  0.8800  0.2388  0.6836  0.9267
# Oceania-America                 0.0748  0.0120  0.6166  0.0001  0.3392
# Oceania-EastAsia                0.0859  0.7261  0.2293  0.3661  0.4366
# America-EastAsia                0.5913  0.2263  0.0866  0.4444  0.5787
#
#                                   5       6       7       8       9     ...  \
# WestEurasia-SouthAsia           0.1114  0.3458  0.7010  0.6163  0.1677  ...
# WestEurasia-Africa              0.0001  1.0000  0.3584  0.3572  0.7694  ...
# WestEurasia-CentralAsiaSiberia  0.2671  0.2059  0.1567  0.1647  0.9123  ...
# WestEurasia-Oceania             0.0001  0.2064  0.1671  0.4162  0.4019  ...
# WestEurasia-America             0.0001  0.1517  0.3997  0.1777  0.4009  ...
# WestEurasia-EastAsia            0.0984  0.0399  0.3655  0.7226  0.7684  ...
# SouthAsia-Africa                0.2061  0.3351  0.7848  0.9815  0.2218  ...
# SouthAsia-CentralAsiaSiberia    0.7746  0.5565  0.5642  0.6185  0.1152  ...
# SouthAsia-Oceania               0.7584  0.5625  0.8045  0.9188  0.1005  ...
# SouthAsia-America               0.7710  0.6672  0.8927  0.5597  0.1132  ...
# SouthAsia-EastAsia              0.9909  0.4849  0.9252  0.9400  0.4825  ...
# Africa-CentralAsiaSiberia       0.2174  0.2161  0.9424  0.9334  0.9518  ...
# Africa-Oceania                  0.0001  0.1135  0.9893  1.0000  0.6750  ...
# Africa-America                  0.0001  0.3259  0.9407  1.0000  0.7454  ...
# Africa-EastAsia                 0.4635  0.1374  0.8325  0.6454  0.4082  ...
# CentralAsiaSiberia-Oceania      0.7786  0.7737  0.9376  0.7872  0.6353  ...
# CentralAsiaSiberia-America      0.7707  0.9005  0.7758  0.8941  0.6753  ...
# CentralAsiaSiberia-EastAsia     0.9310  0.8451  0.8762  0.8920  0.7502  ...
# Oceania-America                 0.0001  0.7383  1.0000  0.4114  0.8622  ...
# Oceania-EastAsia                0.4386  0.8165  0.6814  0.9104  0.3319  ...
# America-EastAsia                0.4790  0.8996  0.4958  0.9777  0.3440  ...
#
#                                   8640    8641    8642    8643    8644  \
# WestEurasia-SouthAsia           0.7255  0.1268  0.4869  0.8451  0.4459
# WestEurasia-Africa              0.1488  0.1717  0.0693  0.1397  0.2631
# WestEurasia-CentralAsiaSiberia  0.7525  0.1164  0.8984  0.7340  0.3670
# WestEurasia-Oceania             0.7953  0.5046  0.3041  0.2987  0.3662
# WestEurasia-America             0.4094  0.1954  0.2016  0.0610  0.7810
# WestEurasia-EastAsia            0.1097  0.3832  0.5941  0.8095  0.2742
# SouthAsia-Africa                0.4714  0.0001  0.0697  0.0750  0.0001
# SouthAsia-CentralAsiaSiberia    0.9736  0.0001  0.5201  0.9665  0.0001
# SouthAsia-Oceania               1.0000  0.3721  0.7239  0.7250  0.0001
# SouthAsia-America               1.0000  0.0001  0.0851  0.0818  0.0001
# SouthAsia-EastAsia              0.4483  0.8127  0.9335  0.9331  0.0001
# Africa-CentralAsiaSiberia       0.3544  0.0001  0.1337  0.3758  0.0001
# Africa-Oceania                  0.3509  0.3022  0.0001  0.0001  0.0001
# Africa-America                  0.0001  0.0001  0.0289  0.0287  0.0001
# Africa-EastAsia                 0.0001  0.8681  0.4512  0.4578  0.0001
# CentralAsiaSiberia-Oceania      0.9905  0.2539  0.2918  1.0000  0.0001
# CentralAsiaSiberia-America      0.9575  0.0001  0.4163  0.1892  0.0001
# CentralAsiaSiberia-EastAsia     0.3466  1.0000  0.3337  0.9979  0.0001
# Oceania-America                 1.0000  1.0000  0.0073  0.0072  0.0001
# Oceania-EastAsia                0.3380  1.0000  0.4492  0.4422  0.0001
# America-EastAsia                0.0001  0.6761  0.1746  0.1804  0.0001
#
#                                   8645    8646    8647    8648    8649
# WestEurasia-SouthAsia           0.7991  0.8711  0.9670  1.0000  0.8762
# WestEurasia-Africa              0.0991  0.0101  0.0109  0.5979  0.2300
# WestEurasia-CentralAsiaSiberia  0.5355  0.8605  0.8573  1.0000  0.5427
# WestEurasia-Oceania             0.3806  0.0001  0.0003  0.9788  0.0046
# WestEurasia-America             0.6599  0.7541  0.7074  0.4115  0.3164
# WestEurasia-EastAsia            0.3092  0.4675  0.4113  1.0000  0.9982
# SouthAsia-Africa                0.2036  0.0281  0.0302  0.7906  0.3082
# SouthAsia-CentralAsiaSiberia    0.5301  0.2080  0.2194  0.0001  0.6283
# SouthAsia-Oceania               0.8898  0.0004  0.0002  0.0001  0.0164
# SouthAsia-America               0.6249  0.6144  0.6215  0.3456  0.3799
# SouthAsia-EastAsia              0.2674  0.1656  0.1646  0.0001  0.8680
# Africa-CentralAsiaSiberia       0.1301  0.0156  0.0142  1.0000  0.1556
# Africa-Oceania                  0.1458  0.0649  0.0637  1.0000  0.1211
# Africa-America                  0.1430  0.1011  0.1028  0.2324  0.9892
# Africa-EastAsia                 0.0177  0.0067  0.0047  0.2244  0.2860
# CentralAsiaSiberia-Oceania      0.0001  0.0002  0.0002  0.0001  0.0057
# CentralAsiaSiberia-America      0.0001  0.5166  0.5200  0.4457  0.1998
# CentralAsiaSiberia-EastAsia     0.0001  0.7759  0.7776  0.0001  0.5511
# Oceania-America                 0.0001  0.0016  0.0020  0.4838  0.1403
# Oceania-EastAsia                0.0001  0.0001  0.0001  0.0001  0.0045
# America-EastAsia                0.0001  0.7565  0.7530  0.2956  0.3520
#
# [21 rows x 8650 columns]

# %%
boolean = (results_permutation<=0.05)


## Deleting columns where none of the regions passed the imputation
boolean = boolean.loc[:, boolean.any()]
boolean
# Out:
#                                  0      1      2      3      5      6     \
# WestEurasia-SouthAsia           False  False  False  False  False  False
# WestEurasia-Africa              False   True   True  False   True  False
# WestEurasia-CentralAsiaSiberia  False  False  False  False  False  False
# WestEurasia-Oceania              True  False  False  False   True  False
# WestEurasia-America             False  False  False  False   True  False
# WestEurasia-EastAsia            False  False  False  False  False   True
# SouthAsia-Africa                False   True   True  False  False  False
# SouthAsia-CentralAsiaSiberia    False  False  False  False  False  False
# SouthAsia-Oceania               False  False  False  False  False  False
# SouthAsia-America               False  False   True  False  False  False
# SouthAsia-EastAsia              False  False  False  False  False  False
# Africa-CentralAsiaSiberia       False   True  False  False  False  False
# Africa-Oceania                   True   True  False   True   True  False
# Africa-America                  False  False  False   True   True  False
# Africa-EastAsia                 False   True   True  False  False  False
# CentralAsiaSiberia-Oceania       True  False  False  False  False  False
# CentralAsiaSiberia-America      False  False  False  False  False  False
# CentralAsiaSiberia-EastAsia     False  False  False  False  False  False
# Oceania-America                 False   True  False   True   True  False
# Oceania-EastAsia                False  False  False  False  False  False
# America-EastAsia                False  False  False  False  False  False
#
#                                  10     12     13     14    ...   8640   8641  \
# WestEurasia-SouthAsia           False  False  False  False  ...  False  False
# WestEurasia-Africa              False  False  False   True  ...  False  False
# WestEurasia-CentralAsiaSiberia  False  False  False   True  ...  False  False
# WestEurasia-Oceania             False  False  False   True  ...  False  False
# WestEurasia-America              True  False  False   True  ...  False  False
# WestEurasia-EastAsia            False  False  False   True  ...  False  False
# SouthAsia-Africa                False   True  False  False  ...  False   True
# SouthAsia-CentralAsiaSiberia    False   True  False  False  ...  False   True
# SouthAsia-Oceania               False   True  False  False  ...  False  False
# SouthAsia-America               False   True  False  False  ...  False   True
# SouthAsia-EastAsia              False   True  False  False  ...  False  False
# Africa-CentralAsiaSiberia       False   True  False   True  ...  False   True
# Africa-Oceania                  False   True  False   True  ...  False  False
# Africa-America                  False   True  False   True  ...   True   True
# Africa-EastAsia                 False   True  False   True  ...   True  False
# CentralAsiaSiberia-Oceania      False   True  False   True  ...  False  False
# CentralAsiaSiberia-America      False   True   True   True  ...  False   True
# CentralAsiaSiberia-EastAsia     False   True   True   True  ...  False  False
# Oceania-America                 False   True  False   True  ...  False  False
# Oceania-EastAsia                False   True   True   True  ...  False  False
# America-EastAsia                 True   True   True   True  ...   True  False
#
#                                  8642   8643   8644   8645   8646   8647  \
# WestEurasia-SouthAsia           False  False  False  False  False  False
# WestEurasia-Africa              False  False  False  False   True   True
# WestEurasia-CentralAsiaSiberia  False  False  False  False  False  False
# WestEurasia-Oceania             False  False  False  False   True   True
# WestEurasia-America             False  False  False  False  False  False
# WestEurasia-EastAsia            False  False  False  False  False  False
# SouthAsia-Africa                False  False   True  False   True   True
# SouthAsia-CentralAsiaSiberia    False  False   True  False  False  False
# SouthAsia-Oceania               False  False   True  False   True   True
# SouthAsia-America               False  False   True  False  False  False
# SouthAsia-EastAsia              False  False   True  False  False  False
# Africa-CentralAsiaSiberia       False  False   True  False   True   True
# Africa-Oceania                   True   True   True  False  False  False
# Africa-America                   True   True   True  False  False  False
# Africa-EastAsia                 False  False   True   True   True   True
# CentralAsiaSiberia-Oceania      False  False   True   True   True   True
# CentralAsiaSiberia-America      False  False   True   True  False  False
# CentralAsiaSiberia-EastAsia     False  False   True   True  False  False
# Oceania-America                  True   True   True   True   True   True
# Oceania-EastAsia                False  False   True   True   True   True
# America-EastAsia                False  False   True   True  False  False
#
#                                  8648   8649
# WestEurasia-SouthAsia           False  False
# WestEurasia-Africa              False  False
# WestEurasia-CentralAsiaSiberia  False  False
# WestEurasia-Oceania             False   True
# WestEurasia-America             False  False
# WestEurasia-EastAsia            False  False
# SouthAsia-Africa                False  False
# SouthAsia-CentralAsiaSiberia     True  False
# SouthAsia-Oceania                True   True
# SouthAsia-America               False  False
# SouthAsia-EastAsia               True  False
# Africa-CentralAsiaSiberia       False  False
# Africa-Oceania                  False  False
# Africa-America                  False  False
# Africa-EastAsia                 False  False
# CentralAsiaSiberia-Oceania       True   True
# CentralAsiaSiberia-America      False  False
# CentralAsiaSiberia-EastAsia      True  False
# Oceania-America                 False  False
# Oceania-EastAsia                 True   True
# America-EastAsia                False  False
#
# [21 rows x 8533 columns]

# %%
name_1 = []
name_2 = []

for i,row in boolean.iterrows():
    ls_1 = [(i.split("-")[0])]
    ls_2 = [i.split("-")[1]]
    #ls_1.append(i.split("-")[0])
    name_1.append(i.split("-")[0])
    name_2.append(i.split("-")[1])
    #ls.append(ls_1)
    #ls.append(ls_2)

# %%
boolean.insert (0, 'group_1', name_1)
boolean.insert (1, 'group_2', name_2)

# %%
boolean
# Out:
#                                            group_1             group_2      0  \
# WestEurasia-SouthAsia                  WestEurasia           SouthAsia  False
# WestEurasia-Africa                     WestEurasia              Africa  False
# WestEurasia-CentralAsiaSiberia         WestEurasia  CentralAsiaSiberia  False
# WestEurasia-Oceania                    WestEurasia             Oceania   True
# WestEurasia-America                    WestEurasia             America  False
# WestEurasia-EastAsia                   WestEurasia            EastAsia  False
# SouthAsia-Africa                         SouthAsia              Africa  False
# SouthAsia-CentralAsiaSiberia             SouthAsia  CentralAsiaSiberia  False
# SouthAsia-Oceania                        SouthAsia             Oceania  False
# SouthAsia-America                        SouthAsia             America  False
# SouthAsia-EastAsia                       SouthAsia            EastAsia  False
# Africa-CentralAsiaSiberia                   Africa  CentralAsiaSiberia  False
# Africa-Oceania                              Africa             Oceania   True
# Africa-America                              Africa             America  False
# Africa-EastAsia                             Africa            EastAsia  False
# CentralAsiaSiberia-Oceania      CentralAsiaSiberia             Oceania   True
# CentralAsiaSiberia-America      CentralAsiaSiberia             America  False
# CentralAsiaSiberia-EastAsia     CentralAsiaSiberia            EastAsia  False
# Oceania-America                            Oceania             America  False
# Oceania-EastAsia                           Oceania            EastAsia  False
# America-EastAsia                           America            EastAsia  False
#
#                                     1      2      3      5      6     10  \
# WestEurasia-SouthAsia           False  False  False  False  False  False
# WestEurasia-Africa               True   True  False   True  False  False
# WestEurasia-CentralAsiaSiberia  False  False  False  False  False  False
# WestEurasia-Oceania             False  False  False   True  False  False
# WestEurasia-America             False  False  False   True  False   True
# WestEurasia-EastAsia            False  False  False  False   True  False
# SouthAsia-Africa                 True   True  False  False  False  False
# SouthAsia-CentralAsiaSiberia    False  False  False  False  False  False
# SouthAsia-Oceania               False  False  False  False  False  False
# SouthAsia-America               False   True  False  False  False  False
# SouthAsia-EastAsia              False  False  False  False  False  False
# Africa-CentralAsiaSiberia        True  False  False  False  False  False
# Africa-Oceania                   True  False   True   True  False  False
# Africa-America                  False  False   True   True  False  False
# Africa-EastAsia                  True   True  False  False  False  False
# CentralAsiaSiberia-Oceania      False  False  False  False  False  False
# CentralAsiaSiberia-America      False  False  False  False  False  False
# CentralAsiaSiberia-EastAsia     False  False  False  False  False  False
# Oceania-America                  True  False   True   True  False  False
# Oceania-EastAsia                False  False  False  False  False  False
# America-EastAsia                False  False  False  False  False   True
#
#                                    12  ...   8640   8641   8642   8643   8644  \
# WestEurasia-SouthAsia           False  ...  False  False  False  False  False
# WestEurasia-Africa              False  ...  False  False  False  False  False
# WestEurasia-CentralAsiaSiberia  False  ...  False  False  False  False  False
# WestEurasia-Oceania             False  ...  False  False  False  False  False
# WestEurasia-America             False  ...  False  False  False  False  False
# WestEurasia-EastAsia            False  ...  False  False  False  False  False
# SouthAsia-Africa                 True  ...  False   True  False  False   True
# SouthAsia-CentralAsiaSiberia     True  ...  False   True  False  False   True
# SouthAsia-Oceania                True  ...  False  False  False  False   True
# SouthAsia-America                True  ...  False   True  False  False   True
# SouthAsia-EastAsia               True  ...  False  False  False  False   True
# Africa-CentralAsiaSiberia        True  ...  False   True  False  False   True
# Africa-Oceania                   True  ...  False  False   True   True   True
# Africa-America                   True  ...   True   True   True   True   True
# Africa-EastAsia                  True  ...   True  False  False  False   True
# CentralAsiaSiberia-Oceania       True  ...  False  False  False  False   True
# CentralAsiaSiberia-America       True  ...  False   True  False  False   True
# CentralAsiaSiberia-EastAsia      True  ...  False  False  False  False   True
# Oceania-America                  True  ...  False  False   True   True   True
# Oceania-EastAsia                 True  ...  False  False  False  False   True
# America-EastAsia                 True  ...   True  False  False  False   True
#
#                                  8645   8646   8647   8648   8649
# WestEurasia-SouthAsia           False  False  False  False  False
# WestEurasia-Africa              False   True   True  False  False
# WestEurasia-CentralAsiaSiberia  False  False  False  False  False
# WestEurasia-Oceania             False   True   True  False   True
# WestEurasia-America             False  False  False  False  False
# WestEurasia-EastAsia            False  False  False  False  False
# SouthAsia-Africa                False   True   True  False  False
# SouthAsia-CentralAsiaSiberia    False  False  False   True  False
# SouthAsia-Oceania               False   True   True   True   True
# SouthAsia-America               False  False  False  False  False
# SouthAsia-EastAsia              False  False  False   True  False
# Africa-CentralAsiaSiberia       False   True   True  False  False
# Africa-Oceania                  False  False  False  False  False
# Africa-America                  False  False  False  False  False
# Africa-EastAsia                  True   True   True  False  False
# CentralAsiaSiberia-Oceania       True   True   True   True   True
# CentralAsiaSiberia-America       True  False  False  False  False
# CentralAsiaSiberia-EastAsia      True  False  False   True  False
# Oceania-America                  True   True   True  False  False
# Oceania-EastAsia                 True   True   True   True   True
# America-EastAsia                 True  False  False  False  False
#
# [21 rows x 8535 columns]

# %% [markdown]
# <h1> Vst group vs allothers

# %%
## Vst
regions = dt['10-Region'].unique()
vst_group_vs_others = []
for region in regions:
        permutation = vst(dt[dt['10-Region'] == region],(dt[dt['10-Region'] != region]))
        vst_group_vs_others.append(permutation)

vt = pd.DataFrame(vst_group_vs_others)
filtering_vst = pd.DataFrame(vt)>=0.2
filtering_vst = filtering_vst.loc[:, filtering_vst.any()]
filtering_vst_allothers = filtering_vst.set_index(regions)
filtering_vst_allothers
# Out:
#                      36     201    455    474    494    510    548    661   \
# WestEurasia         False  False  False   True  False  False  False  False
# SouthAsia           False  False  False  False  False  False  False  False
# Africa              False   True   True  False   True   True  False   True
# CentralAsiaSiberia  False  False  False  False  False  False  False  False
# Oceania             False  False  False  False  False  False  False  False
# America              True  False  False  False  False  False   True  False
# EastAsia            False  False  False  False  False  False  False  False
#
#                      710    740   ...   8284   8306   8307   8322   8405  \
# WestEurasia         False   True  ...  False  False  False  False  False
# SouthAsia           False  False  ...  False  False  False  False  False
# Africa              False  False  ...  False   True   True  False  False
# CentralAsiaSiberia  False  False  ...  False  False  False  False  False
# Oceania             False  False  ...   True  False  False   True  False
# America              True  False  ...  False  False  False  False   True
# EastAsia            False  False  ...  False  False  False  False  False
#
#                      8406   8456   8562   8563   8586
# WestEurasia         False  False  False  False  False
# SouthAsia           False  False  False  False  False
# Africa              False  False  False  False   True
# CentralAsiaSiberia  False  False  False  False  False
# Oceania             False   True  False  False  False
# America              True  False   True   True  False
# EastAsia            False  False  False  False  False
#
# [7 rows x 125 columns]

# %%
## Coordinates anotation 
vt_dt = pd.DataFrame(vst_group_vs_others).set_index(regions).T
vt_dt.insert (0, 'chr', cnv['Chr'])
vt_dt.insert (1, 'start', cnv['Start'])
vt_dt.insert (2, 'end', cnv['End'])
vt_dt = vt_dt.round(5)
vt_dt.sort_values(by='Oceania', ascending=False).head(20)
# Out:
#      chr      start        end  WestEurasia  SouthAsia   Africa  \
# 5207   3  177002636  177011374      0.02419    0.01286  0.01427
# 8456   X   93395090   93408524      0.03981    0.00629  0.01514
# 6393   6   30065894   30068872      0.01587    0.00913  0.00996
# 925   10   91998319   92002307      0.01904    0.00732  0.02014
# 2882  16   85101681   85104890      0.01264    0.00951  0.01041
# 8284   X   31529162   31554252      0.01271    0.00431  0.01622
# 8119   9  131362536  131365905      0.01533    0.00888  0.00691
# 6026   5   79900557   79910136      0.01877    0.00441  0.00513
# 1108  11   21847054   21849813      0.01226    0.01368  0.00366
# 3195  18   12196209   12196772      0.01668    0.00665  0.00480
# 4712  22   50252755   50261847      0.01057    0.00826  0.00897
# 4579  21   44284546   44288276      0.00613    0.00958  0.01048
# 5033   3  110158791  110182347      0.00568    0.00964  0.01056
# 1131  11   26469413   26479421      0.00501    0.00966  0.01058
# 8322   X   44712257   44728537      0.01719    0.00432  0.01064
# 2126  13  104595073  104600742      0.00771    0.00841  0.00914
# 7421   8   22996194   23001045      0.01906    0.01520  0.01984
# 7422   8   23003088   23003688      0.01858    0.01492  0.01853
# 5977   5   57323420   57335861      0.00365    0.00849  0.02328
# 2941  17   10117841   10120538      0.01163    0.00722  0.00777
#
#       CentralAsiaSiberia  Oceania  America  EastAsia
# 5207             0.00971  0.59310  0.00849   0.01485
# 8456             0.00859  0.42783  0.01218   0.00374
# 6393             0.00725  0.35471  0.00652   0.01031
# 925              0.01747  0.34730  0.01468   0.00676
# 2882             0.00751  0.34279  0.00672   0.01078
# 8284             0.00983  0.32973  0.01378   0.00590
# 8119             0.00709  0.30900  0.00639   0.01002
# 6026             0.00811  0.28135  0.00720   0.01189
# 1108             0.00396  0.28011  0.02044   0.01798
# 3195             0.00749  0.27702  0.00671   0.01075
# 4712             0.00668  0.26899  0.00606   0.00926
# 4579             0.00755  0.26784  0.00676   0.01086
# 5033             0.00759  0.26271  0.00679   0.01094
# 1131             0.00760  0.25056  0.00680   0.01096
# 8322             0.00764  0.24791  0.00683   0.01103
# 2126             0.00678  0.24471  0.00614   0.00944
# 7421             0.01125  0.24067  0.00971   0.01769
# 7422             0.01107  0.23895  0.00957   0.01736
# 5977             0.00363  0.23666  0.01948   0.00917
# 2941             0.00599  0.23320  0.00552   0.00800

# %% [markdown]
# <h1> Permutation each group vs all other

# %%
#dt[dt['10-Region'] == region].drop(columns=['7-Gender', '10-Region', '11-Country'])
p_value_permutation = []
for region in regions:
    p_value= []
    p_value_permutation.append(p_value)
    x = dt[dt['10-Region'] == region].drop(columns=['7-Gender', '10-Region', '11-Country'])
    y = dt[dt['10-Region'] != region].drop(columns=['7-Gender', '10-Region', '11-Country'])
    for i in range(10):
        
        permutation = PermutationTest(x[i], y[i], stat=vst_gt, n_perm=9999)
        p_value.append(permutation.p_value())

# %%
p_value_permutation
# Out:
# [[0.771, 0.5588, 0.481, 0.5452, 0.6002, 0.1008, 0.201, 0.3616, 0.3729, 0.9229],
#  [0.8957,
#   0.178,
#   0.1474,
#   0.6276,
#   0.9522,
#   0.1201,
#   0.8075,
#   0.8635,
#   0.7974,
#   0.0678],
#  [0.2495,
#   0.0355,
#   0.0424,
#   0.2957,
#   0.6323,
#   0.2246,
#   0.2151,
#   0.1158,
#   0.1212,
#   0.5882],
#  [0.0818,
#   0.6252,
#   0.4908,
#   0.0427,
#   0.7363,
#   0.0943,
#   0.7442,
#   0.7847,
#   0.7812,
#   0.9332],
#  [0.0046,
#   0.5127,
#   0.3897,
#   0.274,
#   0.3046,
#   0.5882,
#   0.7924,
#   0.9682,
#   0.3821,
#   0.4064],
#  [0.6347,
#   0.1332,
#   0.1243,
#   0.5016,
#   0.0522,
#   0.6459,
#   0.7543,
#   0.4181,
#   0.8746,
#   0.4213],
#  [0.7186,
#   0.9561,
#   0.0453,
#   0.0943,
#   0.9624,
#   0.1225,
#   0.0652,
#   0.8475,
#   0.9259,
#   0.5581]]

# %% [markdown]
# <h2> Permutation results from job

# %%
## Results from permutation_group_vs_allothers.py
results_permutation_allothers = pd.read_csv("../data/permutation_results_group_vs_allothers.csv", index_col=0)
results_permutation_allothers.columns = results_permutation_allothers.columns.astype(int)

# %%
boolean_allothers = (results_permutation_allothers<=0.05)

## Deleting columns where none of the regions passed the imputation
boolean_allothers = boolean_allothers.loc[:, boolean_allothers.any()]

# %%
boolean_allothers
# Out:
#                      0      1      2      3      10     13     14     16    \
# WestEurasia         False  False  False  False  False  False  False  False
# SouthAsia           False  False  False  False  False  False   True  False
# Africa              False   True   True  False  False  False  False  False
# CentralAsiaSiberia  False  False  False   True  False  False  False  False
# Oceania              True  False  False  False  False   True  False  False
# America             False  False  False  False   True  False  False  False
# EastAsia            False  False   True  False  False  False  False   True
#
#                      20     25    ...   8635   8636   8641   8642   8643  \
# WestEurasia          True  False  ...  False   True   True  False  False
# SouthAsia           False  False  ...  False  False  False  False  False
# Africa              False   True  ...  False   True  False  False  False
# CentralAsiaSiberia  False  False  ...   True  False  False  False  False
# Oceania              True  False  ...  False  False  False  False  False
# America             False  False  ...  False  False  False   True   True
# EastAsia            False  False  ...  False  False  False  False  False
#
#                      8644   8645   8646   8647   8649
# WestEurasia          True  False  False  False  False
# SouthAsia           False  False  False  False  False
# Africa              False   True   True   True  False
# CentralAsiaSiberia  False  False  False  False  False
# Oceania             False  False   True   True   True
# America             False  False  False  False  False
# EastAsia            False  False  False  False  False
#
# [7 rows x 4049 columns]

# %% [markdown]
# <h1> Venn diagram

# %%
#PERMUTATION RESULTS
inner_per = len(pd.concat([boolean.T, boolean_allothers.T], axis=1, join="inner"))
left_per = len(boolean.T) - inner_per
right_per = len(boolean_allothers.T) -inner_per


venn2(subsets = (left_per, right_per, inner_per), set_labels = ('Pairwise', '1vsallothers'))
plt.title('Genes that passed permutation in any group(p-value <0.05)')
# Out:
# Text(0.5, 1.0, 'Genes that passed permutation in any group(p-value <0.05)')

# %%
# VST RESULTS 
inner_vst = len(pd.concat([filtering_vst_allothers.T, filtering_vst.T], axis=1, join="inner"))
left_vst = len(filtering_vst.T) - inner_vst
right_vst = len(filtering_vst_allothers.T) -inner_vst


venn2(subsets = (left_vst, right_vst, inner_vst), set_labels = ('Pairwise', '1vsallothers'))
plt.title('Genes that passed vst in any group, vst > 0.2')
plt.show()

# %%
inner_p = pd.concat([boolean.T, boolean_allothers.T], axis=1, join="inner")#pd.concat([boolean.T, boolean_allothers.T], axis=1, join="inner")
inner_v = pd.concat([filtering_vst_allothers.T, filtering_vst.T], axis=1, join="inner")
inner_x = len(pd.concat([inner_v, inner_p],join='inner', axis=1))
left = len(inner_p) - inner_x
right = (inner_vst - inner_x)


venn2(subsets = (int(left), int(right),int(inner_x)),  set_labels = ('Permutation', 'Vst'))
plt.title('Genes that passed vst and permutation in the 2 modes')
plt.show()

# %%
inner_v_pair = filtering_vst.T#pd.concat([filtering_vst_allothers.T, filtering_vst.T], axis=1, join="inner")
inner_x_pair = len(pd.concat([inner_v_pair, inner_p],join='inner', axis=1))
left_pair = len(inner_p) - inner_x_pair
right_pair =  len(inner_v_pair) - inner_x_pair


venn2(subsets = (int(left_pair), int(right_pair),int(inner_x_pair)),  set_labels = ('Permutation', 'Vst-pair'))
plt.title('Genes that passed permutation and vst in pair_groups')
plt.show()

# %%
inner_v = filtering_vst_allothers.T#pd.concat([filtering_vst_allothers.T, filtering_vst.T], axis=1, join="inner")
inner_x = len(pd.concat([inner_v, inner_p],join='inner', axis=1))
left = len(inner_p) - inner_x
right =  len(inner_v) - inner_x


venn2(subsets = (int(left), int(right),int(inner_x)),  set_labels = ('Permutation', 'Vst-allothers'))
plt.title('Genes that passed permutation and vst in all-others')
plt.show()

# %%
fig = plt.figure()

ax = fig.add_axes([0,1,0.9,0.9])
venn2(subsets = (left_per, right_per, inner_per), set_labels = ('Pairwise', '1vsallothers'))
plt.title('Genes that passed permutation in any group(p-value <0.05)')


ax = fig.add_axes([0,0,0.9,0.9])
venn2(subsets = (left_vst, right_vst, inner_vst), set_labels = ('Pairwise', '1vsallothers'))
plt.title('Genes that passed vst in any group, vst > 0.2', loc='left')


ax = fig.add_axes([1,0,0.9,0.9])
venn2(subsets = (int(left), int(right),int(inner_x)),  set_labels = ('Permutation', 'Vst'))
plt.title('Genes that passed vst and permutation in the 2 modes')

#plt.show()

ax = fig.add_axes([1,1,0.9,0.9])
venn2(subsets = (int(left_pair), int(right_pair),int(inner_x_pair)),  set_labels = ('Permutation', 'Vst-pair'))
plt.title('Genes that passed permutation and vst in pair_groups')
# Out:
# Text(0.5, 1.0, 'Genes that passed permutation and vst in pair_groups')

# %%
## Getting genes that pass vst and passed perm in the group

# %%
pd.concat([inner_v, inner_p],join='inner', axis=1).drop(columns=names)
# Out:
#       WestEurasia  SouthAsia  Africa  CentralAsiaSiberia  Oceania  America  \
# 36          False      False   False               False    False     True
# 201         False      False    True               False    False    False
# 455         False      False    True               False    False    False
# 474          True      False   False               False    False    False
# 494         False      False    True               False    False    False
# ...           ...        ...     ...                 ...      ...      ...
# 8406        False      False   False               False    False     True
# 8456        False      False   False               False     True    False
# 8562        False      False   False               False    False     True
# 8563        False      False   False               False    False     True
# 8586        False      False    True               False    False    False
#
#       EastAsia  WestEurasia  SouthAsia  Africa  CentralAsiaSiberia  Oceania  \
# 36       False         True      False    True                True    False
# 201      False        False      False    True                True     True
# 455      False        False      False    True                True    False
# 474      False         True      False    True               False     True
# 494      False        False      False    True               False    False
# ...        ...          ...        ...     ...                 ...      ...
# 8406     False        False      False   False               False    False
# 8456     False         True      False   False               False     True
# 8562     False         True      False   False               False    False
# 8563     False         True      False   False               False    False
# 8586     False         True      False    True               False    False
#
#       America  EastAsia
# 36       True      True
# 201     False      True
# 455     False      True
# 474      True      True
# 494     False      True
# ...       ...       ...
# 8406     True     False
# 8456    False     False
# 8562     True      True
# 8563     True      True
# 8586    False     False
#
# [125 rows x 14 columns]

# %%
vst_hundred_allothers = pd.concat([filtering_vst_allothers.T, filtering_vst.T], axis=1, join="inner").drop(columns=names)
permut_hundred = pd.concat([vst_hundred_allothers, inner_p],join='inner', axis=1).drop(columns=names)
permut_hundred = permut_hundred.iloc[:, 7:15]
vst_hundred_allothers
# Out:
#       WestEurasia  SouthAsia  Africa  CentralAsiaSiberia  Oceania  America  \
# 36          False      False   False               False    False     True
# 201         False      False    True               False    False    False
# 455         False      False    True               False    False    False
# 474          True      False   False               False    False    False
# 510         False      False    True               False    False    False
# ...           ...        ...     ...                 ...      ...      ...
# 8406        False      False   False               False    False     True
# 8456        False      False   False               False     True    False
# 8562        False      False   False               False    False     True
# 8563        False      False   False               False    False     True
# 8586        False      False    True               False    False    False
#
#       EastAsia
# 36       False
# 201      False
# 455      False
# 474      False
# 510      False
# ...        ...
# 8406     False
# 8456     False
# 8562     False
# 8563     False
# 8586     False
#
# [100 rows x 7 columns]

# %%
dist = vst_hundred_allothers.sum()

filtering_vst_allothers.T.sum()

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(dist.index, dist, color ='lightblue',
        width = 0.4)
 
plt.xlabel("Region")
plt.ylabel("# of CNVs")
plt.title("CNVs that passed Vst and permutation in the two modes", size=20)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,4))

#sns.set_palette("bright")
for i in filtering_vst.T.columns:
    plt.hist(vst_dt[i], bins=100, alpha=0.2, log=True, color="blue",  ax=ax[0])
    
    
    

dist = filtering_vst.T.sum()

#fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(dist.index, dist, color ='blue',  ax=ax[1])
 
#plt.xlabel("Pairwise combination")
#plt.ylabel("# of CNVs passed perrmutation")
#plt.title("CNVs that passed Vst(pair-group) and permutation", size=20)
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-814d7b01f014> in <module>
#       3 #sns.set_palette("bright")
#       4 for i in filtering_vst.T.columns:
# ----> 5     plt.hist(vst_dt[i], bins=100, alpha=0.2, log=True, color="blue",  ax=ax[0])
#       6
#       7
#
# /opt/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2688         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2689         color=color, label=label, stacked=stacked,
# -> 2690         **({"data": data} if data is not None else {}), **kwargs)
#    2691
#    2692
#
# TypeError: inner() got multiple values for argument 'ax'

# %%
d = []
for i in filtering_vst.T.columns:
    plt.hist(vst_dt[i], bins=100, alpha=0.2, log=True, color="blue")

# %%
## Keep only cnvs that are >0.2 in X region and passed the permutation in X region too.

# %%
passed = []
for index in vst_hundred_allothers.index:
    for i in regions:
        if vst_hundred_allothers[i][index] == True & permut_hundred[i][index]==True:
            passed.append(index)
            
len(passed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-488dff86eb90> in <module>
#       1 passed = []
# ----> 2 for index in vst_hundred_allothers.index:
#       3     for i in regions:
#       4         if vst_hundred_allothers[i][index] == True & permut_hundred[i][index]==True:
#       5             passed.append(index)
#
# NameError: name 'vst_hundred_allothers' is not defined

# %%
passed = []
a = vst_dt.T>0.2
d= (results_permutation<=0.05).T
for index in a.index:
    for i in combination_names:
        if a[i][index] == True & d[i][index]==True:
            passed.append(index)
            
b = [*set(passed)] ## dropping duplicates 
len(b)
# Out:
# 570

# %%
rna_seq = pd.read_csv('/branchinecta/jbazanwilliamson/rna-seq/GSE54308_gene_fpkm_table.txt', sep='\t')
#https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE54308

# %%
genes_id= pd.read_csv("../data/vst_gene_anotation.csv")
genes_id = genes_id.iloc[:,0:4]
genes_id.columns =['chr', 'start', 'end', 'gene_name']
genes_id = genes_id.replace(23, 'X')
genes_id
# Out:
#      chr      start        end gene_name
# 0      1  100517299  100523294   MFSD14A
# 1      1   10067509   10076124      RBP7
# 2      1    1009660    1015541    RNF223
# 3      1  102395735  102403958     OLFM3
# 4      1   10272327   10278119     KIF1B
# ...   ..        ...        ...       ...
# 3811   X    8766763    8770552     FAM9A
# 3812   X   91366346   91368944   PCDH11X
# 3813   X   96606076   96609958    DIAPH2
# 3814   X   96618876   96624473    DIAPH2
# 3815   X   96672279   96676326    DIAPH2
#
# [3816 rows x 4 columns]

# %%
pd.merge(genes_id, rna_seq, on="gene_name")
# Out:
#      chr      start        end gene_name         tracking_id  \
# 0      1   10067509   10076124      RBP7  ENSG00000162444.10
# 1      1    1009660    1015541    RNF223   ENSG00000237330.1
# 2      1  102395735  102403958     OLFM3  ENSG00000118733.12
# 3      1   10272327   10278119     KIF1B  ENSG00000054523.12
# 4      1   10282248   10326922     KIF1B  ENSG00000054523.12
# ...   ..        ...        ...       ...                 ...
# 2983   X    8766763    8770552     FAM9A   ENSG00000183304.6
# 2984   X   91366346   91368944   PCDH11X  ENSG00000102290.16
# 2985   X   96606076   96609958    DIAPH2  ENSG00000147202.13
# 2986   X   96618876   96624473    DIAPH2  ENSG00000147202.13
# 2987   X   96672279   96676326    DIAPH2  ENSG00000147202.13
#
#                  gene_id             tss  HGDP00711  HGDP00712  HGDP00713  \
# 0     ENSG00000162444.10   chr1:10057263   0.045455   0.000000   0.001535
# 1      ENSG00000237330.1    chr1:1007125   0.000000   0.000000   0.000000
# 2     ENSG00000118733.12  chr1:102268129   0.000685   0.000000   0.000000
# 3     ENSG00000054523.12   chr1:10270862   0.211373   0.659287   0.110827
# 4     ENSG00000054523.12   chr1:10270862   0.211373   0.659287   0.110827
# ...                  ...             ...        ...        ...        ...
# 2983   ENSG00000183304.6    chrX:8758835   0.000000   0.000000   0.000000
# 2984  ENSG00000102290.16   chrX:91034259   0.002381   0.002490   0.001839
# 2985  ENSG00000147202.13   chrX:95939661   1.818720   1.729440   0.503148
# 2986  ENSG00000147202.13   chrX:95939661   1.818720   1.729440   0.503148
# 2987  ENSG00000147202.13   chrX:95939661   1.818720   1.729440   0.503148
#
#       ...  HGDP00992  HGDP01029  HGDP01036  HGDP00948  HGDP00950  HGDP00955  \
# 0     ...   0.000768   0.001357   0.000000   0.000000   0.000000   0.000000
# 1     ...   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 2     ...   0.002227   0.000000   0.000148   0.001233   0.000647   0.000000
# 3     ...   0.213246   0.000000   0.177245   0.721959   0.458517   0.074492
# 4     ...   0.213246   0.000000   0.177245   0.721959   0.458517   0.074492
# ...   ...        ...        ...        ...        ...        ...        ...
# 2983  ...   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 2984  ...   0.000400   0.000264   0.001291   0.003805   0.002114   0.003467
# 2985  ...   0.163489   0.428040   0.651110   1.670460   2.112000   0.630458
# 2986  ...   0.163489   0.428040   0.651110   1.670460   2.112000   0.630458
# 2987  ...   0.163489   0.428040   0.651110   1.670460   2.112000   0.630458
#
#       HGDP00959  HGDP00964  HGDP00967  Unnamed: 49
# 0      0.003153   0.000000   0.000000          NaN
# 1      0.000000   0.000000   0.000000          NaN
# 2      0.000628   0.000080   0.000000          NaN
# 3      0.126583   0.135498   0.179244          NaN
# 4      0.126583   0.135498   0.179244          NaN
# ...         ...        ...        ...          ...
# 2983   0.000000   0.000000   0.000000          NaN
# 2984   0.002364   0.001133   0.001869          NaN
# 2985   1.380020   0.668613   0.979208          NaN
# 2986   1.380020   0.668613   0.979208          NaN
# 2987   1.380020   0.668613   0.979208          NaN
#
# [2988 rows x 53 columns]

# %%
#sns.set_palette("bright")
for i in filtering_vst.T.columns:
    plt.hist(vst_dt[i], bins=100, alpha=0.2, log=True, color="blue")

# %%
# Out:
#       WestEurasia-SouthAsia  WestEurasia-Africa  \
# 36                    False               False
# 37                    False               False
# 49                    False               False
# 51                    False               False
# 55                    False               False
# ...                     ...                 ...
# 8586                  False                True
# 8588                  False               False
# 8646                  False               False
# 8647                  False               False
# 8649                  False               False
#
#       WestEurasia-CentralAsiaSiberia  WestEurasia-Oceania  \
# 36                              True                False
# 37                             False                False
# 49                             False                False
# 51                             False                False
# 55                             False                False
# ...                              ...                  ...
# 8586                           False                False
# 8588                           False                False
# 8646                           False                False
# 8647                           False                False
# 8649                           False                False
#
#       WestEurasia-America  WestEurasia-EastAsia  SouthAsia-Africa  \
# 36                   True                 False             False
# 37                   True                 False             False
# 49                  False                 False             False
# 51                  False                 False             False
# 55                  False                 False             False
# ...                   ...                   ...               ...
# 8586                False                 False             False
# 8588                False                 False             False
# 8646                False                 False             False
# 8647                False                 False             False
# 8649                False                 False             False
#
#       SouthAsia-CentralAsiaSiberia  SouthAsia-Oceania  SouthAsia-America  ...  \
# 36                            True              False               True  ...
# 37                           False              False              False  ...
# 49                           False              False              False  ...
# 51                           False              False              False  ...
# 55                            True              False              False  ...
# ...                            ...                ...                ...  ...
# 8586                         False              False              False  ...
# 8588                         False              False              False  ...
# 8646                         False              False              False  ...
# 8647                         False              False              False  ...
# 8649                         False              False              False  ...
#
#       Africa-CentralAsiaSiberia  Africa-Oceania  Africa-America  \
# 36                         True           False            True
# 37                        False           False            True
# 49                        False            True            True
# 51                        False           False           False
# 55                        False            True           False
# ...                         ...             ...             ...
# 8586                      False           False           False
# 8588                      False           False           False
# 8646                      False           False           False
# 8647                      False           False           False
# 8649                      False           False           False
#
#       Africa-EastAsia  CentralAsiaSiberia-Oceania  CentralAsiaSiberia-America  \
# 36              False                       False                       False
# 37              False                       False                       False
# 49              False                        True                        True
# 51              False                       False                       False
# 55              False                        True                       False
# ...               ...                         ...                         ...
# 8586            False                       False                       False
# 8588            False                       False                       False
# 8646            False                        True                       False
# 8647            False                        True                       False
# 8649            False                        True                       False
#
#       CentralAsiaSiberia-EastAsia  Oceania-America  Oceania-EastAsia  \
# 36                           True             True             False
# 37                          False             True             False
# 49                          False            False             False
# 51                          False            False             False
# 55                          False            False              True
# ...                           ...              ...               ...
# 8586                        False            False             False
# 8588                        False             True             False
# 8646                        False             True              True
# 8647                        False             True              True
# 8649                        False            False             False
#
#       America-EastAsia
# 36                True
# 37               False
# 49               False
# 51                True
# 55               False
# ...                ...
# 8586             False
# 8588             False
# 8646             False
# 8647             False
# 8649             False
#
# [574 rows x 21 columns]

# %%
vst_dt.iloc[:,3:25]
# Out:
#       WestEurasia-SouthAsia  WestEurasia-Africa  \
# 0                   0.00888             0.01589
# 1                   0.01656             0.08613
# 2                   0.01447             0.05338
# 3                   0.01353             0.01351
# 4                   0.01029             0.00848
# ...                     ...                 ...
# 8645                0.00885             0.03265
# 8646                0.00886             0.05787
# 8647                0.00885             0.05665
# 8648                0.01351             0.01582
# 8649                0.00919             0.02007
#
#       WestEurasia-CentralAsiaSiberia  WestEurasia-Oceania  \
# 0                            0.03326              0.04202
# 1                            0.01001              0.01862
# 2                            0.02077              0.02643
# 3                            0.03442              0.01351
# 4                            0.01327              0.01619
# ...                              ...                  ...
# 8645                         0.01718              0.01687
# 8646                         0.01827              0.15949
# 8647                         0.01856              0.15703
# 8648                         0.01351              0.01351
# 8649                         0.01587              0.13343
#
#       WestEurasia-America  WestEurasia-EastAsia  SouthAsia-Africa  \
# 0                 0.01588               0.00841           0.01985
# 1                 0.04420               0.00859           0.12591
# 2                 0.04762               0.01282           0.09619
# 3                 0.01351               0.02386           0.03401
# 4                 0.03137               0.01214           0.01325
# ...                   ...                   ...               ...
# 8645              0.01666               0.01875           0.03368
# 8646              0.01066               0.01285           0.06030
# 8647              0.01072               0.01312           0.06030
# 8648              0.01858               0.01351           0.02273
# 8649              0.02142               0.00841           0.02772
#
#       SouthAsia-CentralAsiaSiberia  SouthAsia-Oceania  SouthAsia-America  ...  \
# 0                          0.04667            0.05705            0.02284  ...
# 1                          0.02153            0.01591            0.07918  ...
# 2                          0.05302            0.05481            0.09950  ...
# 3                          0.02461            0.03169            0.03138  ...
# 4                          0.01577            0.03087            0.03068  ...
# ...                            ...                ...                ...  ...
# 8645                       0.02564            0.02564            0.02564  ...
# 8646                       0.02574            0.19101            0.01681  ...
# 8647                       0.02574            0.19101            0.01681  ...
# 8648                           NaN                NaN            0.04545  ...
# 8649                       0.01929            0.17447            0.03381  ...
#
#       Africa-Oceania  Africa-America  Africa-EastAsia  \
# 0            0.09138         0.01521          0.02111
# 1            0.17269         0.04347          0.08381
# 2            0.01701         0.01521          0.06423
# 3                NaN             NaN          0.04361
# 4            0.02273         0.03380          0.01429
# ...              ...             ...              ...
# 8645         0.05444         0.05275          0.06784
# 8646         0.06213         0.06873          0.09885
# 8647         0.06213         0.06873          0.09885
# 8648         0.02273         0.04892          0.02273
# 8649         0.09335         0.01527          0.02158
#
#       CentralAsiaSiberia-Oceania  CentralAsiaSiberia-America  \
# 0                        0.13688                     0.02606
# 1                        0.02733                     0.04270
# 2                        0.02219                     0.04843
# 3                        0.05488                     0.05409
# 4                        0.03704                     0.03011
# ...                          ...                         ...
# 8645                         NaN                         NaN
# 8646                     0.30299                     0.02814
# 8647                     0.30299                     0.02814
# 8648                         NaN                     0.04545
# 8649                     0.24319                     0.06109
#
#       CentralAsiaSiberia-EastAsia  Oceania-America  Oceania-EastAsia  \
# 0                         0.04539          0.08230           0.04721
# 1                         0.01370          0.11817           0.02574
# 2                         0.03433          0.02487           0.03913
# 3                         0.01549              NaN           0.03723
# 4                         0.01370          0.04545           0.02941
# ...                           ...              ...               ...
# 8645                          NaN              NaN               NaN
# 8646                      0.01498          0.24022           0.25329
# 8647                      0.01498          0.24022           0.25329
# 8648                          NaN          0.04545               NaN
# 8649                      0.02244          0.10717           0.16085
#
#       America-EastAsia       i
# 0              0.02251     0.0
# 1              0.04746     1.0
# 2              0.05833     2.0
# 3              0.03637     3.0
# 4              0.02619     4.0
# ...                ...     ...
# 8645               NaN  8645.0
# 8646           0.01709  8646.0
# 8647           0.01709  8647.0
# 8648           0.04545  8648.0
# 8649           0.02649  8649.0
#
# [8650 rows x 22 columns]
