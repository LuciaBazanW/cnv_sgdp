# %%
import pandas as pd
from scipy import stats
from pyranges import PyRanges

# %%
header_1 = ['Chromosome','Start', 'End', 'Original','Strain']
header_2 = ['Chromosome', 'Start' , 'End']
header_3 = ['Chromosome', 'Start' , 'End', 'Type']
header_4 = ['Chromosome','Start', 'End', 'Type','Strain']

grch37_to_t2t = pd.read_csv('/Users/luciabazan/Downloads/liftover_vsts_grch37_to_t2tchm13.bed', sep='\t', names=header_1)
#grch37_to_t2t = PyRanges(grch37_to_t2t)
''
grch37_to_t2t_types = pd.read_csv('/Users/luciabazan/Downloads/liftover_vsts_grch37_to_t2tchm13_types.bed', sep='\t', names=header_4)

grch37_to_t2t_all = pd.read_csv('/Users/luciabazan/Downloads/liftover_grch37_to_t2tchm13.bed', sep='\t', names=header_1)
grch37_to_t2t_all = PyRanges(grch37_to_t2t_all)

t2t_to_grch37 = pd.read_csv('/Users/luciabazan/Downloads/liftover_vsts_t2tchm13_to_grch37.bed', sep='\t', names=header_1)
t2t_to_grch37 = PyRanges(t2t_to_grch37)

grch37 = pd.read_csv('vst_coordinates_grch37.bed', sep='\t', names=header_3)
grch37 = PyRanges(grch37)

t2t = pd.read_csv('vst_coordinates_chm13t2t.bed', sep='\t', names=header_3)
t2t = PyRanges(t2t)

t2t_all= pd.read_csv('../data/vst_results_t2tchm13.csv')
t2t_all = PyRanges(t2t_all)
#t2t_all

t2t_all_values= pd.read_csv('vst_candidates_chm13t2t.csv')
t2t_all_values = PyRanges(t2t_all_values)


grch37_all_values= pd.read_csv('vst_candidates_grch37.csv')
#grch37_all_values = PyRanges(grch37_all_values)

t2t_all
# Out:
# +--------------+-----------+-----------+-------------+-------+
# | Chromosome   | Start     | End       | Type        | +21   |
# | (category)   | (int64)   | (int64)   | (object)    | ...   |
# |--------------+-----------+-----------+-------------+-------|
# | chr1         | 260453    | 261566    | duplication | ...   |
# | chr1         | 261566    | 263205    | duplication | ...   |
# | chr1         | 263205    | 264505    | duplication | ...   |
# | chr1         | 264505    | 269912    | duplication | ...   |
# | ...          | ...       | ...       | ...         | ...   |
# | chr22        | 51291273  | 51292827  | duplication | ...   |
# | chr22        | 51292827  | 51295018  | duplication | ...   |
# | chr22        | 51295018  | 51296018  | deletion    | ...   |
# | chr22        | 51295018  | 51296018  | duplication | ...   |
# +--------------+-----------+-----------+-------------+-------+
# Unstranded PyRanges object has 1,116,024 rows and 25 columns from 22 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.
# 21 hidden columns: Africa-America, Africa-CentralAsiaSiberia, Africa-EastAsia, ... (+ 18 more.)

# %%
#### GRCh37 vst to T2T vst 
grch37_to_t2t = grch37_to_t2t.merge(grch37_to_t2t_types, on=['Chromosome','Start','End'])
grch37_to_t2t = PyRanges(grch37_to_t2t)
grch37_to_t2t
# Out:
# +--------------+-----------+-----------+-------------------------+-------+
# | Chromosome   | Start     | End       | Original                | +3    |
# | (category)   | (int64)   | (int64)   | (object)                | ...   |
# |--------------+-----------+-----------+-------------------------+-------|
# | chr1         | 7831877   | 7831877   | chr1:8360202-8360201    | ...   |
# | chr1         | 9328929   | 9328929   | chr1:9846202-9846201    | ...   |
# | chr1         | 15268652  | 15268652  | chr1:16150402-16150401  | ...   |
# | chr1         | 23888826  | 23888826  | chr1:24377602-24377601  | ...   |
# | ...          | ...       | ...       | ...                     | ...   |
# | chr22        | 39367662  | 39367662  | chr22:39293302-39293301 | ...   |
# | chr22        | 45005436  | 45005436  | chr22:44917502-44917501 | ...   |
# | chr22        | 45643209  | 45643209  | chr22:45554602-45554601 | ...   |
# | chr22        | 49638819  | 49638819  | chr22:49530202-49530201 | ...   |
# +--------------+-----------+-----------+-------------------------+-------+
# Unstranded PyRanges object has 458 rows and 7 columns from 22 chromosomes.
# For printing, the PyRanges was sorted on Chromosome.
# 3 hidden columns: Strain_x, Type, Strain_y

# %%
#t2t.overlap(grch37_to_t2t)
grch37_to_t2tchm13 = grch37_to_t2t.nearest(t2t_all_values)
grch37_to_t2tchm13 = grch37_to_t2tchm13.as_df()

grch37_to_t2tchm13 = grch37_to_t2tchm13[grch37_to_t2tchm13['Distance'] < 2000]
grch37_to_t2tchm13
# Out:
#     Chromosome      Start        End                  Original  Strain_x  \
# 0         chr1    7831877    7831877      chr1:8360202-8360201         1
# 1         chr1    9328929    9328929      chr1:9846202-9846201         1
# 2         chr1   61526516   61526516    chr1:62113302-62113301         1
# 3         chr1   62067167   62067167    chr1:62654202-62654201         1
# 4         chr1  127795552  127795552  chr1:142781102-142781101         1
# ..         ...        ...        ...                       ...       ...
# 444      chr22   22703853   22703853   chr22:22644702-22644701         1
# 445      chr22   45643209   45643209   chr22:45554602-45554601         1
# 449      chr22   19266007   19266007   chr22:20326502-20326501         1
# 450      chr22   20794933   20794933   chr22:20744902-20744901         1
# 455      chr22   39367662   39367662   chr22:39293302-39293301         1
#
#          Type  Strain_y    Start_b      End_b       Type_b  ...  \
# 0    deletion         1    7831825    7834151     deletion  ...
# 1    deletion         1    9327347    9329877     deletion  ...
# 2    deletion         1   61525294   61528369     deletion  ...
# 3    deletion         1   62054126   62068025     deletion  ...
# 4    deletion         1  127792859  127797357  duplication  ...
# ..        ...       ...        ...        ...          ...  ...
# 444  deletion         1   22698253   22708613  duplication  ...
# 445  deletion         1   45642081   45644771     deletion  ...
# 449  deletion         1   19263623   19265142  duplication  ...
# 450  deletion         1   20791712   20793449  duplication  ...
# 455  deletion         1   39368645   39370943     deletion  ...
#
#      CentralAsiaSiberia-Oceania  CentralAsiaSiberia-SouthAsia  \
# 0                       0.16226                       0.19753
# 1                       0.01544                       0.00997
# 2                       0.00161                       0.04440
# 3                       0.07257                       0.09699
# 4                       0.20184                       0.00313
# ..                          ...                           ...
# 444                     0.01090                       0.02429
# 445                     0.05437                       0.00094
# 449                     0.00358                       0.05670
# 450                     0.01769                       0.08231
# 455                     0.01684                       0.02256
#
#      CentralAsiaSiberia-WestEurasia  EastAsia-Oceania  EastAsia-SouthAsia  \
# 0                           0.23443           0.00000             0.00000
# 1                           0.02872           0.01273             0.01072
# 2                           0.00331           0.03219             0.00487
# 3                           0.07824           0.03515             0.12204
# 4                           0.00016           0.05401             0.00160
# ..                              ...               ...                 ...
# 444                         0.00251           0.03213             0.05583
# 445                         0.04836           0.13517             0.05844
# 449                         0.04769           0.02660             0.15531
# 450                         0.04549           0.03926             0.11747
# 455                         0.00637           0.06979             0.09085
#
#      EastAsia-WestEurasia  Oceania-SouthAsia  Oceania-WestEurasia  \
# 0                 0.00000            0.00000              0.00000
# 1                 0.02922            0.04083              0.00148
# 2                 0.00562            0.06277              0.00850
# 3                 0.12254            0.30360              0.27836
# 4                 0.00396            0.14924              0.09556
# ..                    ...                ...                  ...
# 444               0.02548            0.00489              0.00089
# 445               0.19557            0.05404              0.00340
# 449               0.15192            0.06364              0.05386
# 450               0.09121            0.02702              0.01396
# 455               0.20508            0.00002              0.03952
#
#      SouthAsia-WestEurasia  Distance
# 0                  0.00000         0
# 1                  0.07366         0
# 2                  0.01731         0
# 3                  0.00152         0
# 4                  0.00089         0
# ..                     ...       ...
# 444                0.00890         0
# 445                0.06073         0
# 449                0.00214       866
# 450                0.00002      1485
# 455                0.05734       984
#
# [129 rows x 32 columns]

# %%
## Getting vst values 
grch37_to_t2tchm13[['Chromosome_old','coordinates_old']] = grch37_to_t2tchm13.Original.str.split(":", expand = True)
grch37_to_t2tchm13[['Start_old','End_old']] = grch37_to_t2tchm13.coordinates_old.str.split("-", expand = True)

grch37_to_t2tchm13['End_old'] = grch37_to_t2tchm13['End_old'].astype('int64')
grch37_to_t2tchm13['Start_old'] = grch37_to_t2tchm13['Start_old'].astype('int64')
grch37_to_t2tchm13['Start_old'] = grch37_to_t2tchm13['Start_old'] -1 
grch37_to_t2tchm13
#grch37_to_t2tchm13.astype({'Start_old': 'int64'}).dtypes
# Out:
#     Chromosome      Start        End                  Original  Strain_x  \
# 0         chr1    7831877    7831877      chr1:8360202-8360201         1
# 1         chr1    9328929    9328929      chr1:9846202-9846201         1
# 2         chr1   61526516   61526516    chr1:62113302-62113301         1
# 3         chr1   62067167   62067167    chr1:62654202-62654201         1
# 4         chr1  127795552  127795552  chr1:142781102-142781101         1
# ..         ...        ...        ...                       ...       ...
# 444      chr22   22703853   22703853   chr22:22644702-22644701         1
# 445      chr22   45643209   45643209   chr22:45554602-45554601         1
# 449      chr22   19266007   19266007   chr22:20326502-20326501         1
# 450      chr22   20794933   20794933   chr22:20744902-20744901         1
# 455      chr22   39367662   39367662   chr22:39293302-39293301         1
#
#          Type  Strain_y    Start_b      End_b       Type_b  ...  \
# 0    deletion         1    7831825    7834151     deletion  ...
# 1    deletion         1    9327347    9329877     deletion  ...
# 2    deletion         1   61525294   61528369     deletion  ...
# 3    deletion         1   62054126   62068025     deletion  ...
# 4    deletion         1  127792859  127797357  duplication  ...
# ..        ...       ...        ...        ...          ...  ...
# 444  deletion         1   22698253   22708613  duplication  ...
# 445  deletion         1   45642081   45644771     deletion  ...
# 449  deletion         1   19263623   19265142  duplication  ...
# 450  deletion         1   20791712   20793449  duplication  ...
# 455  deletion         1   39368645   39370943     deletion  ...
#
#      EastAsia-SouthAsia  EastAsia-WestEurasia  Oceania-SouthAsia  \
# 0               0.00000               0.00000            0.00000
# 1               0.01072               0.02922            0.04083
# 2               0.00487               0.00562            0.06277
# 3               0.12204               0.12254            0.30360
# 4               0.00160               0.00396            0.14924
# ..                  ...                   ...                ...
# 444             0.05583               0.02548            0.00489
# 445             0.05844               0.19557            0.05404
# 449             0.15531               0.15192            0.06364
# 450             0.11747               0.09121            0.02702
# 455             0.09085               0.20508            0.00002
#
#      Oceania-WestEurasia  SouthAsia-WestEurasia  Distance  Chromosome_old  \
# 0                0.00000                0.00000         0            chr1
# 1                0.00148                0.07366         0            chr1
# 2                0.00850                0.01731         0            chr1
# 3                0.27836                0.00152         0            chr1
# 4                0.09556                0.00089         0            chr1
# ..                   ...                    ...       ...             ...
# 444              0.00089                0.00890         0           chr22
# 445              0.00340                0.06073         0           chr22
# 449              0.05386                0.00214       866           chr22
# 450              0.01396                0.00002      1485           chr22
# 455              0.03952                0.05734       984           chr22
#
#          coordinates_old  Start_old    End_old
# 0        8360202-8360201    8360201    8360201
# 1        9846202-9846201    9846201    9846201
# 2      62113302-62113301   62113301   62113301
# 3      62654202-62654201   62654201   62654201
# 4    142781102-142781101  142781101  142781101
# ..                   ...        ...        ...
# 444    22644702-22644701   22644701   22644701
# 445    45554602-45554601   45554601   45554601
# 449    20326502-20326501   20326501   20326501
# 450    20744902-20744901   20744901   20744901
# 455    39293302-39293301   39293301   39293301
#
# [129 rows x 36 columns]

# %%
vst_grch37 = grch37_to_t2tchm13.merge(grch37_all_values, left_on=['Start_old','End_old'], right_on=['Start','End'])
vst_grch37 = vst_grch37.drop_duplicates()
vst_grch37
# Out:
#     Chromosome_x    Start_x      End_x                  Original  Strain_x  \
# 0           chr1    7831877    7831877      chr1:8360202-8360201         1
# 1           chr1    9328929    9328929      chr1:9846202-9846201         1
# 2           chr1   61526516   61526516    chr1:62113302-62113301         1
# 3           chr1   62067167   62067167    chr1:62654202-62654201         1
# 4           chr1  127795552  127795552  chr1:142781102-142781101         1
# ..           ...        ...        ...                       ...       ...
# 128        chr22   22703853   22703853   chr22:22644702-22644701         1
# 129        chr22   45643209   45643209   chr22:45554602-45554601         1
# 130        chr22   19266007   19266007   chr22:20326502-20326501         1
# 131        chr22   20794933   20794933   chr22:20744902-20744901         1
# 132        chr22   39367662   39367662   chr22:39293302-39293301         1
#
#        Type_x  Strain_y    Start_b      End_b       Type_b  ...  \
# 0    deletion         1    7831825    7834151     deletion  ...
# 1    deletion         1    9327347    9329877     deletion  ...
# 2    deletion         1   61525294   61528369     deletion  ...
# 3    deletion         1   62054126   62068025     deletion  ...
# 4    deletion         1  127792859  127797357  duplication  ...
# ..        ...       ...        ...        ...          ...  ...
# 128  deletion         1   22698253   22708613  duplication  ...
# 129  deletion         1   45642081   45644771     deletion  ...
# 130  deletion         1   19263623   19265142  duplication  ...
# 131  deletion         1   20791712   20793449  duplication  ...
# 132  deletion         1   39368645   39370943     deletion  ...
#
#      CentralAsiaSiberia-EastAsia_y  CentralAsiaSiberia-Oceania_y  \
# 0                          0.20969                       0.16537
# 1                          0.00322                       0.00473
# 2                          0.03559                       0.02488
# 3                          0.01047                       0.01152
# 4                          0.05890                       0.05239
# ..                             ...                           ...
# 128                        0.28749                       0.30937
# 129                        0.08929                       0.05556
# 130                        0.02340                       0.00089
# 131                        0.05338                       0.00534
# 132                        0.14918                       0.00423
#
#      CentralAsiaSiberia-SouthAsia_y  CentralAsiaSiberia-WestEurasia_y  \
# 0                           0.19923                           0.23576
# 1                           0.02281                           0.01140
# 2                           0.18592                           0.07596
# 3                           0.21087                           0.31966
# 4                           0.08106                           0.00061
# ..                              ...                               ...
# 128                         0.13846                           0.10097
# 129                         0.00066                           0.02389
# 130                         0.02830                           0.04262
# 131                         0.00404                           0.00217
# 132                         0.00003                           0.02288
#
#      EastAsia-Oceania_y  EastAsia-SouthAsia_y  EastAsia-WestEurasia_y  \
# 0               0.00000               0.00000                 0.00000
# 1               0.01292               0.01026                 0.02870
# 2               0.00108               0.05781                 0.01040
# 3               0.04052               0.12127                 0.21908
# 4               0.19897               0.26200                 0.03801
# ..                  ...                   ...                     ...
# 128             0.00362               0.05889                 0.05298
# 129             0.18060               0.08708                 0.21650
# 130             0.01417               0.09036                 0.11544
# 131             0.02776               0.08255                 0.08027
# 132             0.10469               0.15221                 0.25649
#
#      Oceania-SouthAsia_y  Oceania-WestEurasia_y  SouthAsia-WestEurasia_y
# 0                0.00000                0.00000                  0.00000
# 1                0.04041                0.00134                  0.07167
# 2                0.08144                0.01532                  0.01813
# 3                0.30559                0.42130                  0.01496
# 4                0.00238                0.04854                  0.08606
# ..                   ...                    ...                      ...
# 128              0.03225                0.02304                  0.00013
# 129              0.05305                0.00946                  0.03372
# 130              0.03416                0.04662                  0.00520
# 131              0.01668                0.01164                  0.00021
# 132              0.00472                0.04120                  0.02441
#
# [129 rows x 61 columns]

# %%
## correlation
from itertools import combinations
regions = ['Africa', 'CentralAsiaSiberia', 'America','Oceania', 'WestEurasia', 'SouthAsia', 'EastAsia']
regions.sort()
combination_names = []
for i in list(combinations(regions,2)):
    combination_names.append(i[0]+str('-')+i[1])

    
combination_names
# Out:
# ['Africa-America',
#  'Africa-CentralAsiaSiberia',
#  'Africa-EastAsia',
#  'Africa-Oceania',
#  'Africa-SouthAsia',
#  'Africa-WestEurasia',
#  'America-CentralAsiaSiberia',
#  'America-EastAsia',
#  'America-Oceania',
#  'America-SouthAsia',
#  'America-WestEurasia',
#  'CentralAsiaSiberia-EastAsia',
#  'CentralAsiaSiberia-Oceania',
#  'CentralAsiaSiberia-SouthAsia',
#  'CentralAsiaSiberia-WestEurasia',
#  'EastAsia-Oceania',
#  'EastAsia-SouthAsia',
#  'EastAsia-WestEurasia',
#  'Oceania-SouthAsia',
#  'Oceania-WestEurasia',
#  'SouthAsia-WestEurasia']

# %%
for i in range(21):
    plt.figure()
    plt.scatter(vst_grch37[combination_names[i]+str('_y')],vst_grch37[combination_names[i]+str('_x')] )
# Out:
# /var/folders/05/4pfxtbrs5459ytz3j1jhcgt00000gn/T/ipykernel_2382/2136663405.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %%
for i in range(21):
    print(combination_names[i])
    print(stats.spearmanr(vst_grch37[combination_names[i]+str('_y')],vst_grch37[combination_names[i]+str('_x')] ))
# Out:
# Africa-America
# SignificanceResult(statistic=0.8237297801886507, pvalue=4.316898448905712e-33)
# Africa-CentralAsiaSiberia
# SignificanceResult(statistic=0.7477475970650937, pvalue=2.4364248155475435e-24)
# Africa-EastAsia
# SignificanceResult(statistic=0.7837694668563208, pvalue=4.787905758820828e-28)
# Africa-Oceania
# SignificanceResult(statistic=0.8609988554579756, pvalue=4.202989245278798e-39)
# Africa-SouthAsia
# SignificanceResult(statistic=0.8169572595894172, pvalue=3.765264375068154e-32)
# Africa-WestEurasia
# SignificanceResult(statistic=0.8408049969846775, pvalue=1.1847222394498788e-35)
# America-CentralAsiaSiberia
# SignificanceResult(statistic=0.7785357235202701, pvalue=1.8260044722211443e-27)
# America-EastAsia
# SignificanceResult(statistic=0.7769923894431607, pvalue=2.6910212787475685e-27)
# America-Oceania
# SignificanceResult(statistic=0.8036178119262981, pvalue=2.0867283205773238e-30)
# America-SouthAsia
# SignificanceResult(statistic=0.7479855363966544, pvalue=2.3139158479963553e-24)
# America-WestEurasia
# SignificanceResult(statistic=0.8123139367744586, pvalue=1.5794178802170667e-31)
# CentralAsiaSiberia-EastAsia
# SignificanceResult(statistic=0.6577304165273312, pvalue=2.5023354388160346e-17)
# CentralAsiaSiberia-Oceania
# SignificanceResult(statistic=0.7635336124487342, pvalue=6.977573835000705e-26)
# CentralAsiaSiberia-SouthAsia
# SignificanceResult(statistic=0.6919482423085661, pvalue=1.0856788861717595e-19)
# CentralAsiaSiberia-WestEurasia
# SignificanceResult(statistic=0.7636719924039566, pvalue=6.75535954793205e-26)
# EastAsia-Oceania
# SignificanceResult(statistic=0.8284414064643181, pvalue=9.051795848306114e-34)
# EastAsia-SouthAsia
# SignificanceResult(statistic=0.7477953988195414, pvalue=2.4113141331910226e-24)
# EastAsia-WestEurasia
# SignificanceResult(statistic=0.806539033527174, pvalue=8.89717003952711e-31)
# Oceania-SouthAsia
# SignificanceResult(statistic=0.7491507123810147, pvalue=1.795835948438801e-24)
# Oceania-WestEurasia
# SignificanceResult(statistic=0.8257115263250749, pvalue=2.250607526566486e-33)
# SouthAsia-WestEurasia
# SignificanceResult(statistic=0.6540227989764122, pvalue=4.3260895121891914e-17)

# %%
for i in range(21):
    print(combination_names[i])
    print(scipy.stats.pearsonr(vst_grch37[combination_names[i]+str('_y')],vst_grch37[combination_names[i]+str('_x')] ))
# Out:
# Africa-America
# PearsonRResult(statistic=0.8469003345464021, pvalue=1.2163473922750136e-36)
# Africa-CentralAsiaSiberia
# PearsonRResult(statistic=0.7853794583531462, pvalue=3.1481260676051504e-28)
# Africa-EastAsia
# PearsonRResult(statistic=0.8025326800729617, pvalue=2.853686394274473e-30)
# Africa-Oceania
# PearsonRResult(statistic=0.861184199082325, pvalue=3.885228919952508e-39)
# Africa-SouthAsia
# PearsonRResult(statistic=0.8175766038609412, pvalue=3.100290423267603e-32)
# Africa-WestEurasia
# PearsonRResult(statistic=0.82527827985422, pvalue=2.5968398803953102e-33)
# America-CentralAsiaSiberia
# PearsonRResult(statistic=0.7422316116548167, pvalue=7.929538455038271e-24)
# America-EastAsia
# PearsonRResult(statistic=0.8369263500639021, pvalue=4.8002552653073344e-35)
# America-Oceania
# PearsonRResult(statistic=0.7757647769883547, pvalue=3.655289223741648e-27)
# America-SouthAsia
# PearsonRResult(statistic=0.8198625398067089, pvalue=1.5035632721688662e-32)
# America-WestEurasia
# PearsonRResult(statistic=0.8444769696275494, pvalue=3.042048360649855e-36)
# CentralAsiaSiberia-EastAsia
# PearsonRResult(statistic=0.46964789046541383, pvalue=1.9683518797264555e-08)
# CentralAsiaSiberia-Oceania
# PearsonRResult(statistic=0.7730599860569353, pvalue=7.128905097690887e-27)
# CentralAsiaSiberia-SouthAsia
# PearsonRResult(statistic=0.8316704818885289, pvalue=3.0180617035296534e-34)
# CentralAsiaSiberia-WestEurasia
# PearsonRResult(statistic=0.8622207469701657, pvalue=2.4978255823841792e-39)
# EastAsia-Oceania
# PearsonRResult(statistic=0.8482278129822858, pvalue=7.312171786340163e-37)
# EastAsia-SouthAsia
# PearsonRResult(statistic=0.7038836077450354, pvalue=1.3571218215566015e-20)
# EastAsia-WestEurasia
# PearsonRResult(statistic=0.8679519055474043, pvalue=2.031441105489873e-40)
# Oceania-SouthAsia
# PearsonRResult(statistic=0.8346926139756509, pvalue=1.0568951463944437e-34)
# Oceania-WestEurasia
# PearsonRResult(statistic=0.8439605815900878, pvalue=3.69079258413228e-36)
# SouthAsia-WestEurasia
# PearsonRResult(statistic=0.7482093402959312, pvalue=2.2041964531763867e-24)

# %%
grch37_same_type_as_t2t = []
for index,row in vst_grch37.iterrows():
    if row[5] == row[9]:
        #print(row)
        grch37_same_type_as_t2t.append(row)

        
grch37_same_type_as_t2t = pd.DataFrame(grch37_same_type_as_t2t)
grch37_same_type_as_t2t#.iloc[5,:]
# Out:
#     Chromosome_x    Start_x      End_x                  Original  Strain_x  \
# 0           chr1    7831877    7831877      chr1:8360202-8360201         1
# 1           chr1    9328929    9328929      chr1:9846202-9846201         1
# 2           chr1   61526516   61526516    chr1:62113302-62113301         1
# 3           chr1   62067167   62067167    chr1:62654202-62654201         1
# 6           chr1  160575283  160575283  chr1:161408002-161408001         1
# ..           ...        ...        ...                       ...       ...
# 124        chr20    1455145    1455145     chr20:1386602-1386601         1
# 126        chr20   15362128   15362128   chr20:15292502-15292501         1
# 127        chr21   16312569   16312569   chr21:19325502-19325501         1
# 129        chr22   45643209   45643209   chr22:45554602-45554601         1
# 132        chr22   39367662   39367662   chr22:39293302-39293301         1
#
#           Type_x  Strain_y    Start_b      End_b       Type_b  ...  \
# 0       deletion         1    7831825    7834151     deletion  ...
# 1       deletion         1    9327347    9329877     deletion  ...
# 2       deletion         1   61525294   61528369     deletion  ...
# 3       deletion         1   62054126   62068025     deletion  ...
# 6    duplication         1  160566352  160576838  duplication  ...
# ..           ...       ...        ...        ...          ...  ...
# 124     deletion         1    1456918    1465552     deletion  ...
# 126     deletion         1   15364107   15372013     deletion  ...
# 127     deletion         1   16310744   16316990     deletion  ...
# 129     deletion         1   45642081   45644771     deletion  ...
# 132     deletion         1   39368645   39370943     deletion  ...
#
#      CentralAsiaSiberia-EastAsia_y  CentralAsiaSiberia-Oceania_y  \
# 0                          0.20969                       0.16537
# 1                          0.00322                       0.00473
# 2                          0.03559                       0.02488
# 3                          0.01047                       0.01152
# 6                          0.00988                       0.02480
# ..                             ...                           ...
# 124                        0.02347                       0.11852
# 126                        0.00441                       0.20063
# 127                        0.00009                       0.07073
# 129                        0.08929                       0.05556
# 132                        0.14918                       0.00423
#
#      CentralAsiaSiberia-SouthAsia_y  CentralAsiaSiberia-WestEurasia_y  \
# 0                           0.19923                           0.23576
# 1                           0.02281                           0.01140
# 2                           0.18592                           0.07596
# 3                           0.21087                           0.31966
# 6                           0.04508                           0.00002
# ..                              ...                               ...
# 124                         0.00154                           0.00751
# 126                         0.00042                           0.00510
# 127                         0.07574                           0.00000
# 129                         0.00066                           0.02389
# 132                         0.00003                           0.02288
#
#      EastAsia-Oceania_y  EastAsia-SouthAsia_y  EastAsia-WestEurasia_y  \
# 0               0.00000               0.00000                 0.00000
# 1               0.01292               0.01026                 0.02870
# 2               0.00108               0.05781                 0.01040
# 3               0.04052               0.12127                 0.21908
# 6               0.00623               0.01901                 0.00899
# ..                  ...                   ...                     ...
# 124             0.04013               0.03728                 0.05398
# 126             0.13696               0.00801                 0.00015
# 127             0.06766               0.08100                 0.00012
# 129             0.18060               0.08708                 0.21650
# 132             0.10469               0.15221                 0.25649
#
#      Oceania-SouthAsia_y  Oceania-WestEurasia_y  SouthAsia-WestEurasia_y
# 0                0.00000                0.00000                  0.00000
# 1                0.04041                0.00134                  0.07167
# 2                0.08144                0.01532                  0.01813
# 3                0.30559                0.42130                  0.01496
# 6                0.00184                0.02017                  0.04274
# ..                   ...                    ...                      ...
# 124              0.11611                0.09946                  0.00324
# 126              0.21302                0.10938                  0.00927
# 127              0.00011                0.05095                  0.06731
# 129              0.05305                0.00946                  0.03372
# 132              0.00472                0.04120                  0.02441
#
# [109 rows x 61 columns]

# %%
#t2t_all_values[t2t_all_values['End']] = 9351410
vst_t2t = grch37_to_t2tchm13.merge(t2t_all_values, left_on=['Chromosome','Start_b','End_b'], right_on=['Chromosome','Start','End'])
vst_t2t#.iloc[5,:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[126], line 2
#       1 #t2t_all_values[t2t_all_values['End']] = 9351410
# ----> 2 vst_t2t = grch37_to_t2tchm13.merge(t2t_all_values, left_on=['Chromosome','Start_b','End_b'], right_on=['Chromosome','Start','End'])
#       3 vst_t2t
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
#   10101         right_index=right_index,
#   10102         sort=sort,
#   10103         suffixes=suffixes,
#   10104         copy=copy,
#   10105         indicator=indicator,
#   10106         validate=validate,
#   10107     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:645, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     628 def __init__(
#     629     self,
#     630     left: DataFrame | Series,
#    (...)
#     642     validate: str | None = None,
#     643 ) -> None:
#     644     _left = _validate_operand(left)
# --> 645     _right = _validate_operand(right)
#     646     self.left = self.orig_left = _left
#     647     self.right = self.orig_right = _right
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py:2426, in _validate_operand(obj)
#    2424         return obj.to_frame()
#    2425 else:
# -> 2426     raise TypeError(
#    2427         f"Can only merge Series or DataFrame objects, a {type(obj)} was passed"
#    2428     )
#
# TypeError: Can only merge Series or DataFrame objects, a <class 'pyranges.pyranges_main.PyRanges'> was passed

# %%
vst_t2t_same_type_as_grch37 = []
for index,row in vst_t2t.iterrows():
    if row[5] == row[9]:
        #print(row)
        vst_t2t_same_type_as_grch37.append(row)
    #print(row[5], row[17])
    
vst_t2t_same_type_as_grch37 = pd.DataFrame(vst_t2t_same_type_as_grch37)
vst_t2t_same_type_as_grch37#.iloc[-1,:]

# %%
# Out:
#    Chromosome    Start_x      End_x                  Original  Strain_x  \
# 0        chr1    7831877    7831877      chr1:8360202-8360201         1
# 1        chr1    9328929    9328929      chr1:9846202-9846201         1
# 2        chr1   61526516   61526516    chr1:62113302-62113301         1
# 3        chr1   62067167   62067167    chr1:62654202-62654201         1
# 6        chr1   78020207   78020207    chr1:78647102-78647101         1
# 7        chr1  156340662  156340662  chr1:157173602-157173601         1
# 8        chr1  160575283  160575283  chr1:161408002-161408001         1
# 14       chr3   26412002   26412002    chr3:26450902-26450901         1
# 16       chr3  134733401  134733401  chr3:131707802-131707801         1
# 17       chr3  192462292  192462292  chr3:189363402-189363401         1
# 19       chr4  193119555  193119555  chr4:190679902-190679901         1
# 23       chr5   12747756   12747756    chr5:12811002-12811001         1
# 24       chr6  161856851  161856851  chr6:161024902-161024901         1
# 28       chr6  167453827  167453827  chr6:166497502-166497501         1
# 30       chr7  101102580  101102580    chr7:99460702-99460701         1
# 31       chr7  112260179  112260179  chr7:110581902-110581901         1
# 32       chr7  155397565  155397565  chr7:153919402-153919401         1
# 41      chr14   67736804   67736804   chr14:73996002-73996001         1
# 42      chr14   67736804   67736804   chr14:73996002-73996001         1
# 43      chr14   79044336   79044336   chr14:85297002-85297001         1
# 45      chr15   19692181   19692181   chr15:21181302-21181301         1
# 47      chr15   19692181   19692181   chr15:21181302-21181301         1
# 51      chr16   64704148   64704148   chr16:58945802-58945801         1
# 52      chr16   68297482   68297482   chr16:62543602-62543601         1
# 58      chr18   40874737   40874737   chr18:38259802-38259801         1
# 59      chr19   37902333   37902333   chr19:35848502-35848501         1
# 60      chr20    1620739    1620739     chr20:1552202-1552201         1
#
#          Type_x  Strain_y    Start_b      End_b       Type_b  ...  \
# 0      deletion         1    7831825    7834151     deletion  ...
# 1      deletion         1    9327347    9329877     deletion  ...
# 2      deletion         1   61525294   61528369     deletion  ...
# 3      deletion         1   62054126   62068025     deletion  ...
# 6      deletion         1   78021390   78023884     deletion  ...
# 7      deletion         1  156341557  156343901     deletion  ...
# 8   duplication         1  160576838  160578750  duplication  ...
# 14     deletion         1   26412289   26414684     deletion  ...
# 16     deletion         1  134734200  134737553     deletion  ...
# 17     deletion         1  192464051  192466414     deletion  ...
# 19  duplication         1  193119115  193123434  duplication  ...
# 23     deletion         1   12748700   12750227     deletion  ...
# 24  duplication         1  161854784  161858068  duplication  ...
# 28     deletion         1  167455822  167457307     deletion  ...
# 30     deletion         1  101104530  101105780     deletion  ...
# 31     deletion         1  112261362  112264055     deletion  ...
# 32     deletion         1  155398666  155400695     deletion  ...
# 41     deletion         1   67738095   67743527     deletion  ...
# 42     deletion         1   67738095   67743527     deletion  ...
# 43     deletion         1   79045346   79046346     deletion  ...
# 45  duplication         1   19690151   19697139  duplication  ...
# 47  duplication         1   19690151   19697139  duplication  ...
# 51     deletion         1   64705406   64713577     deletion  ...
# 52     deletion         1   68299250   68300868     deletion  ...
# 58     deletion         1   40875226   40880146     deletion  ...
# 59     deletion         1   37903921   37904921     deletion  ...
# 60     deletion         1    1622002    1623108     deletion  ...
#
#     CentralAsiaSiberia-EastAsia CentralAsiaSiberia-Oceania  \
# 0                       0.20833                    0.16226
# 1                      -0.00000                    0.01544
# 2                       0.01987                    0.00161
# 3                       0.00536                    0.07257
# 6                       0.01578                    0.00056
# 7                       0.08376                    0.41104
# 8                       0.04748                    0.07676
# 14                      0.00262                    0.02310
# 16                      0.00023                    0.01017
# 17                      0.02634                    0.13704
# 19                      0.10836                    0.16993
# 23                      0.13927                    0.02588
# 24                      0.00000                    0.05336
# 28                      0.00392                    0.02944
# 30                      0.00000                    0.00000
# 31                      0.04762                    0.00412
# 32                      0.01135                    0.18157
# 41                      0.12099                    0.15746
# 42                      0.00010                    0.40199
# 43                      0.00003                    0.09949
# 45                      0.06588                    0.00759
# 47                      0.06588                    0.00759
# 51                      0.07853                    0.35348
# 52                      0.01410                    0.31186
# 58                      0.00073                    0.14042
# 59                      0.00579                    0.27716
# 60                      0.00065                    0.16267
#
#    CentralAsiaSiberia-SouthAsia  CentralAsiaSiberia-WestEurasia  \
# 0                       0.19753                         0.23443
# 1                       0.00997                         0.02872
# 2                       0.04440                         0.00331
# 3                       0.09699                         0.07824
# 6                       0.01581                         0.01077
# 7                       0.41065                         0.28795
# 8                       0.06860                         0.01937
# 14                      0.00085                         0.04762
# 16                      0.03210                         0.02686
# 17                      0.03541                         0.08116
# 19                      0.01363                         0.00422
# 23                      0.00260                         0.00136
# 24                      0.04123                         0.02782
# 28                      0.02591                         0.00058
# 30                      0.00000                         0.00773
# 31                      0.01258                         0.01096
# 32                      0.00126                         0.00088
# 41                      0.22060                         0.17387
# 42                      0.09016                         0.08700
# 43                      0.00841                         0.00530
# 45                      0.01672                         0.00218
# 47                      0.01672                         0.00218
# 51                      0.05921                         0.00773
# 52                      0.04179                         0.00412
# 58                      0.07977                         0.00623
# 59                      0.10308                         0.11376
# 60                      0.00791                         0.00017
#
#     EastAsia-Oceania  EastAsia-SouthAsia  EastAsia-WestEurasia  \
# 0            0.00000             0.00000               0.00000
# 1            0.01273             0.01072               0.02922
# 2            0.03219             0.00487               0.00562
# 3            0.03515             0.12204               0.12254
# 6            0.02224             0.05917               0.04383
# 7            0.14418             0.15403               0.09398
# 8            0.00957             0.00026               0.00414
# 14           0.00894             0.00673               0.07937
# 16           0.01475             0.04460               0.04138
# 17           0.21990             0.12227               0.20752
# 19           0.00954             0.06800               0.08190
# 23           0.20623             0.09357               0.15009
# 24           0.03476             0.03317               0.02848
# 28           0.01131             0.01201               0.00875
# 30           0.00000             0.00000               0.01087
# 31           0.02920             0.01444               0.01087
# 32           0.14099             0.02720               0.02779
# 41           0.00464             0.01856               0.00643
# 42           0.40552             0.09712               0.11105
# 43           0.08933             0.00978               0.00528
# 45           0.12105             0.01506               0.09775
# 47           0.12105             0.01506               0.09775
# 51           0.16788             0.01185               0.08199
# 52           0.20214             0.07633               0.03619
# 58           0.10955             0.06457               0.00344
# 59           0.10755             0.04042               0.07300
# 60           0.12718             0.00398               0.00008
#
#    Oceania-SouthAsia  Oceania-WestEurasia  SouthAsia-WestEurasia
# 0            0.00000              0.00000                0.00000
# 1            0.04083              0.00148                0.07366
# 2            0.06277              0.00850                0.01731
# 3            0.30360              0.27836                0.00152
# 6            0.01037              0.00673                0.00005
# 7            0.00089              0.01209                0.00981
# 8            0.00871              0.01976                0.00660
# 14           0.03134              0.12253                0.03963
# 16           0.00651              0.00522                0.00002
# 17           0.04805              0.01044                0.01296
# 19           0.12172              0.11385                0.00167
# 23           0.03570              0.01183                0.00736
# 24           0.18091              0.11848                0.00010
# 28           0.00000              0.03878                0.04089
# 30           0.00000              0.00687                0.00977
# 31           0.00218              0.00148                0.00002
# 32           0.24587              0.25214                0.00004
# 41           0.00452              0.00003                0.00316
# 42           0.14463              0.03029                0.01395
# 43           0.03417              0.11161                0.02640
# 45           0.04548              0.00083                0.03254
# 47           0.04548              0.00083                0.03254
# 51           0.24962              0.38512                0.04089
# 52           0.43920              0.36372                0.01477
# 58           0.01196              0.06738                0.03577
# 59           0.03502              0.00239                0.00888
# 60           0.12285              0.07874                0.00384
#
# [27 rows x 39 columns]

# %%
#### GRCh37 vst to T2T all cnvs 
#t2t.overlap(grch37_to_t2t)
grch37_to_t2tchm13 = grch37_to_t2t.nearest(t2t_all)
grch37_to_t2tchm13 = grch37_to_t2tchm13.as_df()
#grch37_to_t2tchm13.sort_values(by='Distance').head(417)
grch37_to_t2tchm13[grch37_to_t2tchm13['Distance']<2000]
# Out:
#     Chromosome     Start       End                 Original  Strain_x  \
# 0         chr1   7831877   7831877     chr1:8360202-8360201         1
# 1         chr1   9328929   9328929     chr1:9846202-9846201         1
# 2         chr1  15268652  15268652   chr1:16150402-16150401         1
# 3         chr1  23888826  23888826   chr1:24377602-24377601         1
# 4         chr1  61526516  61526516   chr1:62113302-62113301         1
# ..         ...       ...       ...                      ...       ...
# 453      chr22  37184554  37184554  chr22:37119802-37119801         1
# 454      chr22  39367662  39367662  chr22:39293302-39293301         1
# 455      chr22  45005436  45005436  chr22:44917502-44917501         1
# 456      chr22  45643209  45643209  chr22:45554602-45554601         1
# 457      chr22  49638819  49638819  chr22:49530202-49530201         1
#
#          Type  Strain_y   Start_b     End_b    Type_b  ...  \
# 0    deletion         1   7831825   7834151  deletion  ...
# 1    deletion         1   9327347   9329877  deletion  ...
# 2    deletion         1  15262571  15273032  deletion  ...
# 3    deletion         1  23884149  23889404  deletion  ...
# 4    deletion         1  61525294  61528369  deletion  ...
# ..        ...       ...       ...       ...       ...  ...
# 453  deletion         1  37182462  37185358  deletion  ...
# 454  deletion         1  39360647  39368645  deletion  ...
# 455  deletion         1  45002433  45008343  deletion  ...
# 456  deletion         1  45642081  45644771  deletion  ...
# 457  deletion         1  49637546  49639487  deletion  ...
#
#      CentralAsiaSiberia-Oceania  CentralAsiaSiberia-SouthAsia  \
# 0                       0.16226                       0.19753
# 1                       0.01544                       0.00997
# 2                       0.00000                       0.00000
# 3                       0.06592                       0.00668
# 4                       0.00161                       0.04440
# ..                          ...                           ...
# 453                     0.01738                       0.00094
# 454                     0.00000                       0.01110
# 455                     0.00877                       0.00836
# 456                     0.05437                       0.00094
# 457                     0.00000                       0.00000
#
#      CentralAsiaSiberia-WestEurasia  EastAsia-Oceania  EastAsia-SouthAsia  \
# 0                           0.23443           0.00000             0.00000
# 1                           0.02872           0.01273             0.01072
# 2                           0.00000           0.00000             0.00000
# 3                           0.01458           0.00000             0.03668
# 4                           0.00331           0.03219             0.00487
# ..                              ...               ...                 ...
# 453                         0.00142           0.00763             0.00138
# 454                         0.00000           0.00763             0.00138
# 455                         0.00521           0.00091             0.00097
# 456                         0.04836           0.13517             0.05844
# 457                         0.00000           0.00763             0.01030
#
#      EastAsia-WestEurasia  Oceania-SouthAsia  Oceania-WestEurasia  \
# 0                 0.00000            0.00000              0.00000
# 1                 0.02922            0.04083              0.00148
# 2                 0.00000            0.00000              0.00000
# 3                 0.01803            0.03027              0.01295
# 4                 0.00562            0.06277              0.00850
# ..                    ...                ...                  ...
# 453               0.00044            0.01009              0.01404
# 454               0.01379            0.01009              0.00000
# 455               0.00164            0.00000              0.00005
# 456               0.19557            0.05404              0.00340
# 457               0.01379            0.00000              0.00000
#
#      SouthAsia-WestEurasia  Distance
# 0                  0.00000         0
# 1                  0.07366         0
# 2                  0.00000         0
# 3                  0.00208         0
# 4                  0.01731         0
# ..                     ...       ...
# 453                0.00446         0
# 454                0.01738         0
# 455                0.00009         0
# 456                0.06073         0
# 457                0.00000         0
#
# [420 rows x 32 columns]

# %%
## Getting vst values 
grch37_to_t2tchm13[['Chromosome_old','coordinates_old']] = grch37_to_t2tchm13.Original.str.split(":", expand = True)
grch37_to_t2tchm13[['Start_old','End_old']] = grch37_to_t2tchm13.coordinates_old.str.split("-", expand = True)

grch37_to_t2tchm13['End_old'] = grch37_to_t2tchm13['End_old'].astype('int64')
grch37_to_t2tchm13['Start_old'] = grch37_to_t2tchm13['Start_old'].astype('int64')
grch37_to_t2tchm13['Start_old'] = grch37_to_t2tchm13['Start_old'] -1 
grch37_to_t2tchm13
#grch37_to_t2tchm13.astype({'Start_old': 'int64'}).dtypes
# Out:
#     Chromosome     Start       End                 Original  Strain_x  \
# 0         chr1   7831877   7831877     chr1:8360202-8360201         1
# 1         chr1   9328929   9328929     chr1:9846202-9846201         1
# 2         chr1  15268652  15268652   chr1:16150402-16150401         1
# 3         chr1  23888826  23888826   chr1:24377602-24377601         1
# 4         chr1  61526516  61526516   chr1:62113302-62113301         1
# ..         ...       ...       ...                      ...       ...
# 453      chr22  37184554  37184554  chr22:37119802-37119801         1
# 454      chr22  39367662  39367662  chr22:39293302-39293301         1
# 455      chr22  45005436  45005436  chr22:44917502-44917501         1
# 456      chr22  45643209  45643209  chr22:45554602-45554601         1
# 457      chr22  49638819  49638819  chr22:49530202-49530201         1
#
#          Type  Strain_y   Start_b     End_b    Type_b  ...  \
# 0    deletion         1   7831825   7834151  deletion  ...
# 1    deletion         1   9327347   9329877  deletion  ...
# 2    deletion         1  15262571  15273032  deletion  ...
# 3    deletion         1  23884149  23889404  deletion  ...
# 4    deletion         1  61525294  61528369  deletion  ...
# ..        ...       ...       ...       ...       ...  ...
# 453  deletion         1  37182462  37185358  deletion  ...
# 454  deletion         1  39360647  39368645  deletion  ...
# 455  deletion         1  45002433  45008343  deletion  ...
# 456  deletion         1  45642081  45644771  deletion  ...
# 457  deletion         1  49637546  49639487  deletion  ...
#
#      EastAsia-SouthAsia  EastAsia-WestEurasia  Oceania-SouthAsia  \
# 0               0.00000               0.00000            0.00000
# 1               0.01072               0.02922            0.04083
# 2               0.00000               0.00000            0.00000
# 3               0.03668               0.01803            0.03027
# 4               0.00487               0.00562            0.06277
# ..                  ...                   ...                ...
# 453             0.00138               0.00044            0.01009
# 454             0.00138               0.01379            0.01009
# 455             0.00097               0.00164            0.00000
# 456             0.05844               0.19557            0.05404
# 457             0.01030               0.01379            0.00000
#
#      Oceania-WestEurasia  SouthAsia-WestEurasia  Distance  Chromosome_old  \
# 0                0.00000                0.00000         0            chr1
# 1                0.00148                0.07366         0            chr1
# 2                0.00000                0.00000         0            chr1
# 3                0.01295                0.00208         0            chr1
# 4                0.00850                0.01731         0            chr1
# ..                   ...                    ...       ...             ...
# 453              0.01404                0.00446         0           chr22
# 454              0.00000                0.01738         0           chr22
# 455              0.00005                0.00009         0           chr22
# 456              0.00340                0.06073         0           chr22
# 457              0.00000                0.00000         0           chr22
#
#        coordinates_old  Start_old   End_old
# 0      8360202-8360201    8360201   8360201
# 1      9846202-9846201    9846201   9846201
# 2    16150402-16150401   16150401  16150401
# 3    24377602-24377601   24377601  24377601
# 4    62113302-62113301   62113301  62113301
# ..                 ...        ...       ...
# 453  37119802-37119801   37119801  37119801
# 454  39293302-39293301   39293301  39293301
# 455  44917502-44917501   44917501  44917501
# 456  45554602-45554601   45554601  45554601
# 457  49530202-49530201   49530201  49530201
#
# [458 rows x 36 columns]

# %%
vst_grch37 = grch37_to_t2tchm13.merge(grch37_all_values, left_on=['Start_old','End_old'], right_on=['Start','End'])
vst_grch37 = vst_grch37.drop_duplicates()
vst_grch37
# Out:
#     Chromosome_x   Start_x     End_x                 Original  Strain_x  \
# 0           chr1   7831877   7831877     chr1:8360202-8360201         1
# 1           chr1   9328929   9328929     chr1:9846202-9846201         1
# 2           chr1  15268652  15268652   chr1:16150402-16150401         1
# 3           chr1  23888826  23888826   chr1:24377602-24377601         1
# 4           chr1  61526516  61526516   chr1:62113302-62113301         1
# ..           ...       ...       ...                      ...       ...
# 463        chr22  37184554  37184554  chr22:37119802-37119801         1
# 464        chr22  39367662  39367662  chr22:39293302-39293301         1
# 465        chr22  45005436  45005436  chr22:44917502-44917501         1
# 466        chr22  45643209  45643209  chr22:45554602-45554601         1
# 467        chr22  49638819  49638819  chr22:49530202-49530201         1
#
#        Type_x  Strain_y   Start_b     End_b    Type_b  ...  \
# 0    deletion         1   7831825   7834151  deletion  ...
# 1    deletion         1   9327347   9329877  deletion  ...
# 2    deletion         1  15262571  15273032  deletion  ...
# 3    deletion         1  23884149  23889404  deletion  ...
# 4    deletion         1  61525294  61528369  deletion  ...
# ..        ...       ...       ...       ...       ...  ...
# 463  deletion         1  37182462  37185358  deletion  ...
# 464  deletion         1  39360647  39368645  deletion  ...
# 465  deletion         1  45002433  45008343  deletion  ...
# 466  deletion         1  45642081  45644771  deletion  ...
# 467  deletion         1  49637546  49639487  deletion  ...
#
#      CentralAsiaSiberia-EastAsia_y  CentralAsiaSiberia-Oceania_y  \
# 0                          0.20969                       0.16537
# 1                          0.00322                       0.00473
# 2                          0.00396                       0.36782
# 3                          0.06462                       0.32327
# 4                          0.03559                       0.02488
# ..                             ...                           ...
# 463                        0.00025                       0.00014
# 464                        0.14918                       0.00423
# 465                        0.01995                       0.27350
# 466                        0.08929                       0.05556
# 467                        0.00000                       0.20930
#
#      CentralAsiaSiberia-SouthAsia_y  CentralAsiaSiberia-WestEurasia_y  \
# 0                           0.19923                           0.23576
# 1                           0.02281                           0.01140
# 2                           0.18162                           0.13144
# 3                           0.00452                           0.02047
# 4                           0.18592                           0.07596
# ..                              ...                               ...
# 463                         0.03479                           0.00032
# 464                         0.00003                           0.02288
# 465                         0.10292                           0.19060
# 466                         0.00066                           0.02389
# 467                         0.00000                           0.01032
#
#      EastAsia-Oceania_y  EastAsia-SouthAsia_y  EastAsia-WestEurasia_y  \
# 0               0.00000               0.00000                 0.00000
# 1               0.01292               0.01026                 0.02870
# 2               0.28087               0.14513                 0.12031
# 3               0.09120               0.04025                 0.01070
# 4               0.00108               0.05781                 0.01040
# ..                  ...                   ...                     ...
# 463             0.00002               0.03548                 0.00001
# 464             0.10469               0.15221                 0.25649
# 465             0.13043               0.03126                 0.09333
# 466             0.18060               0.08708                 0.21650
# 467             0.24731               0.00000                 0.01473
#
#      Oceania-SouthAsia_y  Oceania-WestEurasia_y  SouthAsia-WestEurasia_y
# 0                0.00000                0.00000                  0.00000
# 1                0.04041                0.00134                  0.07167
# 2                0.03382                0.03128                  0.00041
# 3                0.24554                0.13059                  0.00854
# 4                0.08144                0.01532                  0.01813
# ..                   ...                    ...                      ...
# 463              0.03005                0.00005                  0.03625
# 464              0.00472                0.04120                  0.02441
# 465              0.06478                0.02026                  0.01602
# 466              0.05305                0.00946                  0.03372
# 467              0.23636                0.17821                  0.01328
#
# [460 rows x 61 columns]

# %%
for i in range(21):
    plt.figure()
    plt.scatter(vst_grch37[combination_names[i]+str('_y')],vst_grch37[combination_names[i]+str('_x')] )
# Out:
# /var/folders/05/4pfxtbrs5459ytz3j1jhcgt00000gn/T/ipykernel_2382/2136663405.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %%
for i in range(21):
    print(combination_names[i])
    print(scipy.stats.pearsonr(vst_grch37[combination_names[i]+str('_y')],vst_grch37[combination_names[i]+str('_x')] ))
# Out:
# Africa-America
# PearsonRResult(statistic=0.3304644474146836, pvalue=3.4968079214602544e-13)
# Africa-CentralAsiaSiberia
# PearsonRResult(statistic=0.27711910162553316, pvalue=1.4831592987592883e-09)
# Africa-EastAsia
# PearsonRResult(statistic=0.2933810166383543, pvalue=1.3903725034563806e-10)
# Africa-Oceania
# PearsonRResult(statistic=0.29713167634868715, pvalue=7.880514434376189e-11)
# Africa-SouthAsia
# PearsonRResult(statistic=0.3269532345609033, pvalue=6.390306136773553e-13)
# Africa-WestEurasia
# PearsonRResult(statistic=0.3309455372076211, pvalue=3.217594659673108e-13)
# America-CentralAsiaSiberia
# PearsonRResult(statistic=0.19602822141711346, pvalue=2.2952365348476786e-05)
# America-EastAsia
# PearsonRResult(statistic=0.2693577120060099, pvalue=4.352644103726052e-09)
# America-Oceania
# PearsonRResult(statistic=0.294454538735619, pvalue=1.1828289669050811e-10)
# America-SouthAsia
# PearsonRResult(statistic=0.29348927465650765, pvalue=1.3679313456835255e-10)
# America-WestEurasia
# PearsonRResult(statistic=0.32216003252967723, pvalue=1.4373412565082378e-12)
# CentralAsiaSiberia-EastAsia
# PearsonRResult(statistic=0.3253798772503679, pvalue=8.351495004390331e-13)
# CentralAsiaSiberia-Oceania
# PearsonRResult(statistic=0.33852805308998013, pvalue=8.50107078600442e-14)
# CentralAsiaSiberia-SouthAsia
# PearsonRResult(statistic=0.3729199074572763, pvalue=1.263907592353583e-16)
# CentralAsiaSiberia-WestEurasia
# PearsonRResult(statistic=0.4391749136963697, pvalue=4.113952569254622e-23)
# EastAsia-Oceania
# PearsonRResult(statistic=0.27127714700578803, pvalue=3.345736141672247e-09)
# EastAsia-SouthAsia
# PearsonRResult(statistic=0.16998846090136605, pvalue=0.0002496517669951193)
# EastAsia-WestEurasia
# PearsonRResult(statistic=0.338485232508854, pvalue=8.566095945612571e-14)
# Oceania-SouthAsia
# PearsonRResult(statistic=0.2517719257454927, pvalue=4.4090175931982854e-08)
# Oceania-WestEurasia
# PearsonRResult(statistic=0.24830083220231536, pvalue=6.825763449845432e-08)
# SouthAsia-WestEurasia
# PearsonRResult(statistic=0.2395236940711751, pvalue=2.0025004655375204e-07)

# %%
#### GRCh37 all CNVs to T2T all CNVs  
#t2t.overlap(grch37_to_t2t)
grch37_to_t2tchm13 = grch37_to_t2t_all.nearest(t2t_all)
grch37_to_t2tchm13 = grch37_to_t2tchm13.as_df()
grch37_to_t2tchm13[grch37_to_t2tchm13['Distance'] < 2000]
# Out:
#      Chromosome     Start       End  Original  Strain   Start_b     End_b  \
# 0          chr1    385106    385106  deletion       1    385084    387761
# 1          chr1    502515    502515  deletion       1    502101    503101
# 2          chr1    542636    542636  deletion       1    540598    544980
# 3          chr1    578336    578336  deletion       1    576150    578407
# 4          chr1    730467    730467  deletion       1    729845    731135
# ...         ...       ...       ...       ...     ...       ...       ...
# 7777      chr22  50867222  50867222  deletion       1  50855753  50870216
# 7778      chr22  51159529  51159529  deletion       1  51153132  51170297
# 7779      chr22  51186640  51186640  deletion       1  51186380  51187482
# 7780      chr22  51201464  51201464  deletion       1  51200518  51202141
# 7781      chr22  51245253  51245253  deletion       1  51243861  51245263
#
#              Type  Africa-America  Africa-CentralAsiaSiberia  ...  \
# 0     duplication         0.06949                    0.29305  ...
# 1        deletion         0.00813                    0.00134  ...
# 2        deletion         0.06195                    0.00624  ...
# 3        deletion         0.00813                    0.00134  ...
# 4        deletion         0.01654                    0.01996  ...
# ...           ...             ...                        ...  ...
# 7777     deletion         0.00000                    0.02266  ...
# 7778     deletion         0.00000                    0.02266  ...
# 7779     deletion         0.01455                    0.02797  ...
# 7780     deletion         0.00000                    0.00000  ...
# 7781     deletion         0.00211                    0.00565  ...
#
#       CentralAsiaSiberia-Oceania  CentralAsiaSiberia-SouthAsia  \
# 0                        0.18037                       0.06042
# 1                        0.01738                       0.02199
# 2                        0.08309                       0.02049
# 3                        0.00027                       0.01592
# 4                        0.00000                       0.02256
# ...                          ...                           ...
# 7777                     0.01738                       0.00094
# 7778                     0.01738                       0.02199
# 7779                     0.00877                       0.00193
# 7780                     0.00000                       0.00000
# 7781                     0.01098                       0.02199
#
#       CentralAsiaSiberia-WestEurasia  EastAsia-Oceania  EastAsia-SouthAsia  \
# 0                            0.09813           0.02709             0.00145
# 1                            0.02721           0.00000             0.00000
# 2                            0.04922           0.00026             0.02701
# 3                            0.02721           0.00000             0.01369
# 4                            0.01172           0.00000             0.02924
# ...                              ...               ...                 ...
# 7777                         0.02721           0.01390             0.00578
# 7778                         0.00058           0.00763             0.01030
# 7779                         0.00119           0.00063             0.00838
# 7780                         0.00000           0.00763             0.01030
# 7781                         0.00058           0.00477             0.01030
#
#       EastAsia-WestEurasia  Oceania-SouthAsia  Oceania-WestEurasia  \
# 0                  0.00187            0.04083              0.01295
# 1                  0.00000            0.00000              0.00000
# 2                  0.00367            0.02013              0.00151
# 3                  0.02783            0.01192              0.03330
# 4                  0.01645            0.02052              0.01042
# ...                    ...                ...                  ...
# 7777               0.02500            0.01009              0.00000
# 7778               0.00131            0.00000              0.00687
# 7779               0.00829            0.01890              0.01507
# 7780               0.01379            0.00000              0.00000
# 7781               0.00131            0.05601              0.01593
#
#       SouthAsia-WestEurasia  Distance
# 0                   0.00638         0
# 1                   0.00000         0
# 2                   0.00961         0
# 3                   0.07150         0
# 4                   0.00063         0
# ...                     ...       ...
# 7777                0.01738         0
# 7778                0.00977         0
# 7779                0.00004         0
# 7780                0.00000         0
# 7781                0.00977         0
#
# [7282 rows x 30 columns]

# %%
## Getting vst values 
grch37_to_t2tchm13[['Chromosome_old','coordinates_old']] = grch37_to_t2tchm13.Original.str.split(":", expand = True)
grch37_to_t2tchm13[['Start_old','End_old']] = grch37_to_t2tchm13.coordinates_old.str.split("-", expand = True)

grch37_to_t2tchm13['End_old'] = grch37_to_t2tchm13['End_old'].astype('int64')
grch37_to_t2tchm13['Start_old'] = grch37_to_t2tchm13['Start_old'].astype('int64')
grch37_to_t2tchm13['Start_old'] = grch37_to_t2tchm13['Start_old'] -1 
grch37_to_t2tchm13
#grch37_to_t2tchm13.astype({'Start_old': 'int64'}).dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[111], line 2
#       1 ## Getting vst values
# ----> 2 grch37_to_t2tchm13[['Chromosome_old','coordinates_old']] = grch37_to_t2tchm13.Original.str.split(":", expand = True)
#       3 grch37_to_t2tchm13[['Start_old','End_old']] = grch37_to_t2tchm13.coordinates_old.str.split("-", expand = True)
#       5 grch37_to_t2tchm13['End_old'] = grch37_to_t2tchm13['End_old'].astype('int64')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3968, in DataFrame.__setitem__(self, key, value)
#    3966     self._setitem_frame(key, value)
#    3967 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3968     self._setitem_array(key, value)
#    3969 elif isinstance(value, DataFrame):
#    3970     self._set_item_frame_value(key, value)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4010, in DataFrame._setitem_array(self, key, value)
#    4005 else:
#    4006     # Note: unlike self.iloc[:, indexer] = value, this will
#    4007     #  never try to overwrite values inplace
#    4009     if isinstance(value, DataFrame):
# -> 4010         check_key_length(self.columns, key, value)
#    4011         for k1, k2 in zip(key, value.columns):
#    4012             self[k1] = value[k2]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexers/utils.py:401, in check_key_length(columns, key, value)
#     399 if columns.is_unique:
#     400     if len(value.columns) != len(key):
# --> 401         raise ValueError("Columns must be same length as key")
#     402 else:
#     403     # Missing keys in columns are represented as -1
#     404     if len(columns.get_indexer_non_unique(key)[0]) != len(value.columns):
#
# ValueError: Columns must be same length as key

# %%
# Using liftover with 0.95 of min map 

T2T = [10759,454]
GRCH37 = [376, 3]
input_chi = pd.DataFrame([T2T, GRCH37])
input_chi.columns = ['T2T_to_GRCh37', 'GRCh37_to_T2T']
input_chi.index = ['Converted', 'No converted']
input_chi

# %%
# Using liftover with 0.95 of min map 

T2T = [10791,454]
GRCH37 = [344, 3]
input_chi = pd.DataFrame([T2T, GRCH37])
input_chi.columns = ['T2T_to_GRCh37', 'GRCh37_to_T2T']
input_chi.index = ['Converted', 'No converted']
input_chi

# %%
from scipy import stats

# %%
stats.chi2_contingency(input_chi)

# %%
#### GRCh37 to T2T
#t2t.overlap(grch37_to_t2t)
grch37_to_t2tchm13 = grch37_to_t2t_all.nearest(t2t)
grch37_to_t2tchm13 = grch37_to_t2tchm13.as_df()
grch37_to_t2tchm13.sort_values(by='Distance').head(275)

# %%
grch37_to_t2tchm13 = t2t.nearest(grch37_to_t2t_all)
grch37_to_t2tchm13 = grch37_to_t2tchm13.as_df()
grch37_to_t2tchm13.sort_values(by='Distance').head(336)

# %%
grch37_to_t2tchm13 = t2t_all.nearest(grch37_to_t2t_all)
grch37_to_t2tchm13 = grch37_to_t2tchm13.as_df()
grch37_to_t2tchm13[grch37_to_t2tchm13['Distance'] < 2000]

# %% [markdown]
# <h1> Confusion matrix
# <h4>Confusion matrix of litfovers (True positives and True Negatives; both assemblies, False positive to T2TCHM13, False negative to T2TCHM13)

# %%
header_1 = ['Chromosome','Start', 'End', 'Original','Strain']
header_2 = ['Chromosome', 'Start' , 'End']
header_3 = ['Chromosome', 'Start' , 'End', 'Type']

grch37_to_t2t = pd.read_csv('/Users/luciabazan/Downloads/liftover_vsts_grch37_to_t2tchm13.bed', sep='\t', names=header_1)
grch37_to_t2t = PyRanges(grch37_to_t2t)

grch37_to_t2t_all = pd.read_csv('/Users/luciabazan/Downloads/liftover_grch37_to_t2tchm13.bed', sep='\t', names=header_1)
grch37_to_t2t_all = PyRanges(grch37_to_t2t_all)

t2t_to_grch37 = pd.read_csv('/Users/luciabazan/Downloads/liftover_vsts_t2tchm13_to_grch37.bed', sep='\t', names=header_1)
t2t_to_grch37 = PyRanges(t2t_to_grch37)

grch37 = pd.read_csv('vst_coordinates_grch37.bed', sep='\t', names=header_2)
grch37 = PyRanges(grch37)

t2t = pd.read_csv('vst_coordinates_chm13t2t.bed', sep='\t', names=header_3)
t2t = PyRanges(t2t)

t2t_all= pd.read_csv('cnvs_coordinates_chm13t2t.bed', sep='\t', names=header_3)
t2t_all = PyRanges(t2t_all)
t2t_all

t2t_all_values= pd.read_csv('../data/vst_results_t2tchm13.csv')
#t2t_all_values = PyRanges(t2t_all_values)


grch37_all_values= pd.read_csv('../data/vst_results_grch37.csv')
#grch37_all_values = PyRanges(grch37_all_values)
grch37_all_values

# %%
#### GRCh37 vst to T2T vst 
#t2t.overlap(grch37_to_t2t)
grch37_to_t2tchm13 = grch37_to_t2t.nearest(t2t)
grch37_to_t2tchm13 = grch37_to_t2tchm13.as_df()


#grch37_to_t2tchm13 = grch37_to_t2tchm13[grch37_to_t2tchm13['Distance'] < 2000]
grch37_to_t2tchm13.sort_values(by=['Distance']).head(50)

# %%
## Getting vst values 
grch37_to_t2tchm13[['Chromosome_old','coordinates_old']] = grch37_to_t2tchm13.Original.str.split(":", expand = True)
grch37_to_t2tchm13[['Start_old','End_old']] = grch37_to_t2tchm13.coordinates_old.str.split("-", expand = True)

grch37_to_t2tchm13['End_old'] = grch37_to_t2tchm13['End_old'].astype('int64')
grch37_to_t2tchm13['Start_old'] = grch37_to_t2tchm13['Start_old'].astype('int64')
#grch37_to_t2tchm13.astype({'Start_old': 'int64'}).dtypes

# %%
vst_grch37 = grch37_to_t2tchm13.merge(grch37_all_values, left_on='End_old', right_on='End')
vst_t2t = grch37_to_t2tchm13.merge(t2t_all_values, left_on=['Chromosome','Start_b','End_b'], right_on=['Chromosome','Start','End'])
vst_t2t
